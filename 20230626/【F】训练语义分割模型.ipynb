# %% [markdown]
# # 训练语义分割模型
#
# 同济子豪兄 2023-2-13 6-12 6-25

# %% [markdown]
# ## 进入MMSegmentation主目录

# %%
import os
os.chdir('mmsegmentation')

# %%
os.getcwd()
# Out:
# '/home/featurize/work/MMSegmentation教程20230625/mmsegmentation'

# %% [markdown]
# ## 载入config配置文件（任选一个运行）

# %%
from mmengine import Config

# %%
# # UNet
# cfg = Config.fromfile('ZihaoDataset_UNet_20230626.py')

# %%
# PSPNet(推荐)
cfg = Config.fromfile('ZihaoDataset_PSPNet_20230626.py')

# %%
# # KNet
# cfg = Config.fromfile('ZihaoDataset_KNet_20230626.py')

# %%
# # SegFormer
# cfg = Config.fromfile('ZihaoDataset_SegFormer_20230626.py')

# %%
# # Mask2Former
# cfg = Config.fromfile('ZihaoDataset_Mask2Former_20230626.py')

# %% [markdown]
# ## 准备训练

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 06/26 21:26:05 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/26 21:26:06 - mmengine - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(64, 64))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(128, 128)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=6,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'ZihaoDataset'
# data_root = 'Watermelon87_Semantic_Seg_Mask/'
# crop_size = (128, 128)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='ZihaoDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(64, 64), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ZihaoDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ZihaoDataset',
#         data_root='Watermelon87_Semantic_Seg_Mask/',
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(
#     type='IoUMetric', iou_metrics=['mIoU', 'mDice', 'mFscore'])
# test_evaluator = dict(
#     type='IoUMetric', iou_metrics=['mIoU', 'mDice', 'mFscore'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=40000, val_interval=500)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         by_epoch=False,
#         interval=2500,
#         max_keep_ckpts=2,
#         save_best='mIoU'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# work_dir = './work_dirs/ZihaoDataset-PSPNet'
# randomness = dict(seed=0)
# /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 06/26 21:26:13 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/26 21:26:13 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %% [markdown]
# ## 开始训练
#
# 如果遇到报错`CUDA out of memeory`，可尝试以下步骤：
#
# 1. 调小 batch size
#
# 2. 左上角`内核-关闭所有内核`
#
# 3. 重启实例，或者使用显存更高的实例即可。

# %%
runner.train()
# Out:
# 06/26 21:26:17 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 06/26 21:26:17 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 06/26 21:26:17 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# Downloading: "https://download.openmmlab.com/pretrain/third_party/resnet50_v1c-2cccc1ad.pth" to /home/featurize/.cache/torch/hub/checkpoints/resnet50_v1c-2cccc1ad.pth
# 06/26 21:26:25 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 06/26 21:26:25 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/26 21:26:25 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/26 21:26:25 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet.
# 06/26 21:26:28 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:26:28 - mmengine - INFO - Iter(train) [   12/40000]  lr: 9.9975e-03  eta: 2:23:51  time: 0.1116  data_time: 0.0594  memory: 18073  loss: 0.5298  decode.loss_ce: 0.3677  decode.acc_seg: 30.4199  aux.loss_ce: 0.1622  aux.acc_seg: 18.2495
# 06/26 21:26:34 - mmengine - INFO - Iter(train) [  100/40000]  lr: 9.9779e-03  eta: 1:00:09  time: 0.0792  data_time: 0.0288  memory: 1253  loss: 0.3976  decode.loss_ce: 0.2926  decode.acc_seg: 67.4133  aux.loss_ce: 0.1050  aux.acc_seg: 70.6543
# 06/26 21:26:42 - mmengine - INFO - Iter(train) [  200/40000]  lr: 9.9557e-03  eta: 0:55:17  time: 0.0776  data_time: 0.0240  memory: 1253  loss: 0.2984  decode.loss_ce: 0.2138  decode.acc_seg: 80.2551  aux.loss_ce: 0.0846  aux.acc_seg: 93.3350
# 06/26 21:26:49 - mmengine - INFO - Iter(train) [  300/40000]  lr: 9.9334e-03  eta: 0:54:00  time: 0.0747  data_time: 0.0216  memory: 1253  loss: 0.1971  decode.loss_ce: 0.1356  decode.acc_seg: 96.5393  aux.loss_ce: 0.0615  aux.acc_seg: 94.4580
# 06/26 21:26:57 - mmengine - INFO - Iter(train) [  400/40000]  lr: 9.9111e-03  eta: 0:53:35  time: 0.0759  data_time: 0.0217  memory: 1253  loss: 0.2184  decode.loss_ce: 0.1546  decode.acc_seg: 74.4141  aux.loss_ce: 0.0638  aux.acc_seg: 74.4690
# 06/26 21:27:05 - mmengine - INFO - Iter(train) [  500/40000]  lr: 9.8888e-03  eta: 0:53:11  time: 0.0567  data_time: 0.0051  memory: 1253  loss: 0.2549  decode.loss_ce: 0.1821  decode.acc_seg: 56.9092  aux.loss_ce: 0.0728  aux.acc_seg: 53.9490
# 06/26 21:27:13 - mmengine - INFO - per class results:
# 06/26 21:27:13 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 72.19 | 81.41 | 83.85 | 83.85  |   86.44   | 81.41  |
# |    red     | 64.94 | 98.03 | 78.74 | 78.74  |    65.8   | 98.03  |
# |   green    |  0.18 |  0.18 |  0.35 |  0.35  |   99.81   |  0.18  |
# |   white    | 35.82 | 37.64 | 52.75 | 52.75  |   88.11   | 37.64  |
# | seed-black | 10.03 | 39.15 | 18.23 | 18.23  |   11.88   | 39.15  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:27:13 - mmengine - INFO - Iter(val) [11/11]    aAcc: 76.8900  mIoU: 30.5300  mAcc: 42.7400  mDice: 38.9900  mFscore: 46.7900  mPrecision: 70.4100  mRecall: 42.7400  data_time: 0.0312  time: 0.6751
# 06/26 21:27:15 - mmengine - INFO - The best checkpoint with 30.5300 mIoU at 500 iter is saved to best_mIoU_iter_500.pth.
# 06/26 21:27:22 - mmengine - INFO - Iter(train) [  600/40000]  lr: 9.8665e-03  eta: 0:54:47  time: 0.0787  data_time: 0.0201  memory: 17407  loss: 0.2286  decode.loss_ce: 0.1617  decode.acc_seg: 69.6899  aux.loss_ce: 0.0669  aux.acc_seg: 72.0642
# 06/26 21:27:31 - mmengine - INFO - Iter(train) [  700/40000]  lr: 9.8442e-03  eta: 0:54:32  time: 0.0818  data_time: 0.0248  memory: 1253  loss: 0.2235  decode.loss_ce: 0.1628  decode.acc_seg: 68.9148  aux.loss_ce: 0.0608  aux.acc_seg: 70.8862
# 06/26 21:27:39 - mmengine - INFO - Iter(train) [  800/40000]  lr: 9.8218e-03  eta: 0:54:18  time: 0.1033  data_time: 0.0462  memory: 1253  loss: 0.1935  decode.loss_ce: 0.1361  decode.acc_seg: 95.4163  aux.loss_ce: 0.0574  aux.acc_seg: 95.4773
# 06/26 21:27:47 - mmengine - INFO - Iter(train) [  900/40000]  lr: 9.7995e-03  eta: 0:53:40  time: 0.0651  data_time: 0.0099  memory: 1253  loss: 0.2147  decode.loss_ce: 0.1533  decode.acc_seg: 91.1926  aux.loss_ce: 0.0614  aux.acc_seg: 88.9648
# 06/26 21:27:55 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:27:55 - mmengine - INFO - Iter(train) [ 1000/40000]  lr: 9.7772e-03  eta: 0:53:37  time: 0.0902  data_time: 0.0307  memory: 1253  loss: 0.2483  decode.loss_ce: 0.1790  decode.acc_seg: 57.1228  aux.loss_ce: 0.0693  aux.acc_seg: 60.8154
# 06/26 21:27:56 - mmengine - INFO - per class results:
# 06/26 21:27:56 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 76.81 | 88.55 | 86.88 | 86.88  |   85.28   | 88.55  |
# |    red     | 72.98 | 99.63 | 84.38 | 84.38  |   73.18   | 99.63  |
# |   green    |  0.57 |  0.57 |  1.13 |  1.13  |   54.34   |  0.57  |
# |   white    | 32.23 | 32.96 | 48.75 | 48.75  |   93.57   | 32.96  |
# | seed-black | 12.39 | 12.53 | 22.05 | 22.05  |   91.91   | 12.53  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:27:56 - mmengine - INFO - Iter(val) [11/11]    aAcc: 81.0800  mIoU: 32.5000  mAcc: 39.0400  mDice: 40.5300  mFscore: 48.6400  mPrecision: 79.6600  mRecall: 39.0400  data_time: 0.0100  time: 0.1036
# 06/26 21:27:56 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet/best_mIoU_iter_500.pth is removed
# 06/26 21:27:58 - mmengine - INFO - The best checkpoint with 32.5000 mIoU at 1000 iter is saved to best_mIoU_iter_1000.pth.
# 06/26 21:28:06 - mmengine - INFO - Iter(train) [ 1100/40000]  lr: 9.7549e-03  eta: 0:54:27  time: 0.0907  data_time: 0.0346  memory: 1707  loss: 0.1563  decode.loss_ce: 0.1120  decode.acc_seg: 82.8247  aux.loss_ce: 0.0443  aux.acc_seg: 80.2856
# 06/26 21:28:14 - mmengine - INFO - Iter(train) [ 1200/40000]  lr: 9.7325e-03  eta: 0:54:09  time: 0.0825  data_time: 0.0242  memory: 1253  loss: 0.2157  decode.loss_ce: 0.1552  decode.acc_seg: 59.5947  aux.loss_ce: 0.0605  aux.acc_seg: 61.6516
# 06/26 21:28:22 - mmengine - INFO - Iter(train) [ 1300/40000]  lr: 9.7102e-03  eta: 0:53:55  time: 0.0621  data_time: 0.0056  memory: 1253  loss: 0.1833  decode.loss_ce: 0.1324  decode.acc_seg: 96.2585  aux.loss_ce: 0.0510  aux.acc_seg: 92.4438
# 06/26 21:28:31 - mmengine - INFO - Iter(train) [ 1400/40000]  lr: 9.6878e-03  eta: 0:53:48  time: 0.0749  data_time: 0.0064  memory: 1253  loss: 0.2040  decode.loss_ce: 0.1453  decode.acc_seg: 85.3271  aux.loss_ce: 0.0587  aux.acc_seg: 88.8000
# 06/26 21:28:39 - mmengine - INFO - Iter(train) [ 1500/40000]  lr: 9.6655e-03  eta: 0:53:29  time: 0.0808  data_time: 0.0268  memory: 1253  loss: 0.1886  decode.loss_ce: 0.1331  decode.acc_seg: 85.6750  aux.loss_ce: 0.0555  aux.acc_seg: 80.9631
# 06/26 21:28:40 - mmengine - INFO - per class results:
# 06/26 21:28:40 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 82.86 | 96.58 | 90.63 | 90.63  |   85.37   | 96.58  |
# |    red     | 86.85 | 94.28 | 92.96 | 92.96  |   91.67   | 94.28  |
# |   green    |  5.48 |  5.51 | 10.39 | 10.39  |   90.39   |  5.51  |
# |   white    | 57.19 |  62.4 | 72.76 | 72.76  |   87.25   |  62.4  |
# | seed-black | 54.82 | 74.43 | 70.82 | 70.82  |   67.54   | 74.43  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:28:40 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.0900  mIoU: 47.8700  mAcc: 55.5300  mDice: 56.2600  mFscore: 67.5100  mPrecision: 84.4400  mRecall: 55.5300  data_time: 0.0119  time: 0.1051
# 06/26 21:28:40 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet/best_mIoU_iter_1000.pth is removed
# 06/26 21:28:41 - mmengine - INFO - The best checkpoint with 47.8700 mIoU at 1500 iter is saved to best_mIoU_iter_1500.pth.
# 06/26 21:28:49 - mmengine - INFO - Iter(train) [ 1600/40000]  lr: 9.6431e-03  eta: 0:53:31  time: 0.0597  data_time: 0.0049  memory: 1707  loss: 0.2398  decode.loss_ce: 0.1713  decode.acc_seg: 56.1157  aux.loss_ce: 0.0684  aux.acc_seg: 52.4475
# 06/26 21:28:56 - mmengine - INFO - Iter(train) [ 1700/40000]  lr: 9.6207e-03  eta: 0:53:12  time: 0.0881  data_time: 0.0338  memory: 1253  loss: 0.2325  decode.loss_ce: 0.1668  decode.acc_seg: 77.7100  aux.loss_ce: 0.0657  aux.acc_seg: 77.1729
# 06/26 21:29:04 - mmengine - INFO - Iter(train) [ 1800/40000]  lr: 9.5983e-03  eta: 0:52:50  time: 0.0831  data_time: 0.0280  memory: 1253  loss: 0.2219  decode.loss_ce: 0.1579  decode.acc_seg: 52.0020  aux.loss_ce: 0.0640  aux.acc_seg: 52.5879
# 06/26 21:29:12 - mmengine - INFO - Iter(train) [ 1900/40000]  lr: 9.5760e-03  eta: 0:52:28  time: 0.0590  data_time: 0.0060  memory: 1253  loss: 0.1525  decode.loss_ce: 0.1080  decode.acc_seg: 70.2637  aux.loss_ce: 0.0445  aux.acc_seg: 71.8079
# 06/26 21:29:20 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:29:20 - mmengine - INFO - Iter(train) [ 2000/40000]  lr: 9.5536e-03  eta: 0:52:11  time: 0.0801  data_time: 0.0300  memory: 1253  loss: 0.1824  decode.loss_ce: 0.1301  decode.acc_seg: 84.0759  aux.loss_ce: 0.0523  aux.acc_seg: 88.0676
# 06/26 21:29:21 - mmengine - INFO - per class results:
# 06/26 21:29:21 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 80.67 | 91.03 |  89.3 |  89.3  |   87.63   | 91.03  |
# |    red     | 79.26 | 98.56 | 88.43 | 88.43  |   80.19   | 98.56  |
# |   green    |  0.7  |  0.7  |  1.39 |  1.39  |   98.08   |  0.7   |
# |   white    | 65.93 | 71.04 | 79.47 | 79.47  |   90.17   | 71.04  |
# | seed-black | 44.09 | 63.53 |  61.2 |  61.2  |   59.03   | 63.53  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:29:21 - mmengine - INFO - Iter(val) [11/11]    aAcc: 85.1600  mIoU: 45.1100  mAcc: 54.1400  mDice: 53.3000  mFscore: 63.9600  mPrecision: 83.0200  mRecall: 54.1400  data_time: 0.0086  time: 0.1009
# 06/26 21:29:29 - mmengine - INFO - Iter(train) [ 2100/40000]  lr: 9.5312e-03  eta: 0:52:02  time: 0.1013  data_time: 0.0455  memory: 1707  loss: 0.2267  decode.loss_ce: 0.1648  decode.acc_seg: 55.8105  aux.loss_ce: 0.0619  aux.acc_seg: 54.7974
# 06/26 21:29:36 - mmengine - INFO - Iter(train) [ 2200/40000]  lr: 9.5088e-03  eta: 0:51:39  time: 0.0798  data_time: 0.0249  memory: 1253  loss: 0.2087  decode.loss_ce: 0.1499  decode.acc_seg: 73.9136  aux.loss_ce: 0.0587  aux.acc_seg: 75.1526
# 06/26 21:29:44 - mmengine - INFO - Iter(train) [ 2300/40000]  lr: 9.4864e-03  eta: 0:51:27  time: 0.0614  data_time: 0.0100  memory: 1253  loss: 0.1923  decode.loss_ce: 0.1379  decode.acc_seg: 74.8718  aux.loss_ce: 0.0544  aux.acc_seg: 72.4304
# 06/26 21:29:52 - mmengine - INFO - Iter(train) [ 2400/40000]  lr: 9.4640e-03  eta: 0:51:13  time: 0.0811  data_time: 0.0271  memory: 1253  loss: 0.1853  decode.loss_ce: 0.1329  decode.acc_seg: 81.1340  aux.loss_ce: 0.0524  aux.acc_seg: 80.5359
# 06/26 21:29:59 - mmengine - INFO - Iter(train) [ 2500/40000]  lr: 9.4416e-03  eta: 0:50:52  time: 0.0750  data_time: 0.0213  memory: 1253  loss: 0.2377  decode.loss_ce: 0.1709  decode.acc_seg: 73.7122  aux.loss_ce: 0.0668  aux.acc_seg: 78.7292
# 06/26 21:29:59 - mmengine - INFO - Saving checkpoint at 2500 iterations
# 06/26 21:30:03 - mmengine - INFO - per class results:
# 06/26 21:30:03 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.92 | 94.45 | 92.43 | 92.43  |   90.49   | 94.45  |
# |    red     | 87.13 | 97.78 | 93.12 | 93.12  |   88.89   | 97.78  |
# |   green    | 18.92 | 19.27 | 31.82 | 31.82  |   91.09   | 19.27  |
# |   white    | 63.15 | 80.98 | 77.41 | 77.41  |   74.15   | 80.98  |
# | seed-black | 47.53 | 48.52 | 64.43 | 64.43  |   95.89   | 48.52  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:30:03 - mmengine - INFO - Iter(val) [11/11]    aAcc: 88.8300  mIoU: 50.4400  mAcc: 56.8300  mDice: 59.8700  mFscore: 71.8400  mPrecision: 88.1000  mRecall: 56.8300  data_time: 0.0095  time: 0.1019
# 06/26 21:30:03 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet/best_mIoU_iter_1500.pth is removed
# 06/26 21:30:04 - mmengine - INFO - The best checkpoint with 50.4400 mIoU at 2500 iter is saved to best_mIoU_iter_2500.pth.
# 06/26 21:30:14 - mmengine - INFO - Iter(train) [ 2600/40000]  lr: 9.4191e-03  eta: 0:51:24  time: 0.0780  data_time: 0.0258  memory: 1707  loss: 0.1617  decode.loss_ce: 0.1178  decode.acc_seg: 86.7676  aux.loss_ce: 0.0438  aux.acc_seg: 80.1941
# 06/26 21:30:22 - mmengine - INFO - Iter(train) [ 2700/40000]  lr: 9.3967e-03  eta: 0:51:13  time: 0.0888  data_time: 0.0355  memory: 1253  loss: 0.1499  decode.loss_ce: 0.1083  decode.acc_seg: 72.0947  aux.loss_ce: 0.0416  aux.acc_seg: 73.4619
# 06/26 21:30:30 - mmengine - INFO - Iter(train) [ 2800/40000]  lr: 9.3743e-03  eta: 0:51:01  time: 0.0978  data_time: 0.0414  memory: 1253  loss: 0.1888  decode.loss_ce: 0.1329  decode.acc_seg: 72.1008  aux.loss_ce: 0.0559  aux.acc_seg: 66.2292
# 06/26 21:30:37 - mmengine - INFO - Iter(train) [ 2900/40000]  lr: 9.3518e-03  eta: 0:50:43  time: 0.0555  data_time: 0.0057  memory: 1253  loss: 0.1662  decode.loss_ce: 0.1171  decode.acc_seg: 87.2864  aux.loss_ce: 0.0491  aux.acc_seg: 86.3770
# 06/26 21:30:45 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:30:45 - mmengine - INFO - Iter(train) [ 3000/40000]  lr: 9.3294e-03  eta: 0:50:28  time: 0.0646  data_time: 0.0056  memory: 1253  loss: 0.1876  decode.loss_ce: 0.1352  decode.acc_seg: 55.1270  aux.loss_ce: 0.0524  aux.acc_seg: 62.9395
# 06/26 21:30:46 - mmengine - INFO - per class results:
# 06/26 21:30:46 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  84.3 | 94.86 | 91.48 | 91.48  |   88.34   | 94.86  |
# |    red     | 81.55 | 90.19 | 89.84 | 89.84  |   89.49   | 90.19  |
# |   green    | 17.13 | 17.64 | 29.25 | 29.25  |   85.56   | 17.64  |
# |   white    | 62.23 | 83.78 | 76.72 | 76.72  |   70.75   | 83.78  |
# | seed-black | 55.84 | 59.48 | 71.67 | 71.67  |   90.13   | 59.48  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:30:46 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.1900  mIoU: 50.1800  mAcc: 57.6600  mDice: 59.8300  mFscore: 71.7900  mPrecision: 84.8500  mRecall: 57.6600  data_time: 0.0107  time: 0.1045
# 06/26 21:30:54 - mmengine - INFO - Iter(train) [ 3100/40000]  lr: 9.3069e-03  eta: 0:50:15  time: 0.0644  data_time: 0.0058  memory: 1707  loss: 0.1545  decode.loss_ce: 0.1105  decode.acc_seg: 76.1230  aux.loss_ce: 0.0440  aux.acc_seg: 76.2695
# 06/26 21:31:02 - mmengine - INFO - Iter(train) [ 3200/40000]  lr: 9.2845e-03  eta: 0:50:11  time: 0.0613  data_time: 0.0057  memory: 1253  loss: 0.2718  decode.loss_ce: 0.1957  decode.acc_seg: 54.3152  aux.loss_ce: 0.0761  aux.acc_seg: 55.0842
# 06/26 21:31:10 - mmengine - INFO - Iter(train) [ 3300/40000]  lr: 9.2620e-03  eta: 0:49:58  time: 0.0801  data_time: 0.0276  memory: 1253  loss: 0.2224  decode.loss_ce: 0.1605  decode.acc_seg: 56.0852  aux.loss_ce: 0.0619  aux.acc_seg: 60.8887
# 06/26 21:31:18 - mmengine - INFO - Iter(train) [ 3400/40000]  lr: 9.2395e-03  eta: 0:49:48  time: 0.0590  data_time: 0.0072  memory: 1253  loss: 0.1476  decode.loss_ce: 0.1021  decode.acc_seg: 93.1519  aux.loss_ce: 0.0455  aux.acc_seg: 93.4326
# 06/26 21:31:26 - mmengine - INFO - Iter(train) [ 3500/40000]  lr: 9.2171e-03  eta: 0:49:38  time: 0.1181  data_time: 0.0635  memory: 1253  loss: 0.2168  decode.loss_ce: 0.1508  decode.acc_seg: 88.8855  aux.loss_ce: 0.0661  aux.acc_seg: 88.8428
# 06/26 21:31:27 - mmengine - INFO - per class results:
# 06/26 21:31:27 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.38 | 95.99 | 92.11 | 92.11  |   88.53   | 95.99  |
# |    red     | 84.92 | 89.69 | 91.84 | 91.84  |    94.1   | 89.69  |
# |   green    | 25.38 |  26.7 | 40.48 | 40.48  |   83.73   |  26.7  |
# |   white    |  57.3 | 79.46 | 72.85 | 72.85  |   67.25   | 79.46  |
# | seed-black | 45.98 | 56.89 | 62.99 | 62.99  |   70.56   | 56.89  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:31:27 - mmengine - INFO - Iter(val) [11/11]    aAcc: 88.0400  mIoU: 49.8200  mAcc: 58.1200  mDice: 60.0500  mFscore: 72.0600  mPrecision: 80.8400  mRecall: 58.1200  data_time: 0.0080  time: 0.1016
# 06/26 21:31:35 - mmengine - INFO - Iter(train) [ 3600/40000]  lr: 9.1946e-03  eta: 0:49:25  time: 0.0812  data_time: 0.0281  memory: 1707  loss: 0.1709  decode.loss_ce: 0.1245  decode.acc_seg: 48.1079  aux.loss_ce: 0.0464  aux.acc_seg: 47.0581
# 06/26 21:31:42 - mmengine - INFO - Iter(train) [ 3700/40000]  lr: 9.1721e-03  eta: 0:49:11  time: 0.0778  data_time: 0.0255  memory: 1253  loss: 0.2032  decode.loss_ce: 0.1441  decode.acc_seg: 88.6414  aux.loss_ce: 0.0591  aux.acc_seg: 90.1062
# 06/26 21:31:50 - mmengine - INFO - Iter(train) [ 3800/40000]  lr: 9.1496e-03  eta: 0:48:59  time: 0.0813  data_time: 0.0267  memory: 1253  loss: 0.1760  decode.loss_ce: 0.1260  decode.acc_seg: 87.5488  aux.loss_ce: 0.0500  aux.acc_seg: 87.6221
# 06/26 21:31:58 - mmengine - INFO - Iter(train) [ 3900/40000]  lr: 9.1271e-03  eta: 0:48:46  time: 0.0881  data_time: 0.0343  memory: 1253  loss: 0.2368  decode.loss_ce: 0.1680  decode.acc_seg: 84.7534  aux.loss_ce: 0.0688  aux.acc_seg: 83.9478
# 06/26 21:32:06 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:32:06 - mmengine - INFO - Iter(train) [ 4000/40000]  lr: 9.1046e-03  eta: 0:48:40  time: 0.0862  data_time: 0.0264  memory: 1253  loss: 0.1582  decode.loss_ce: 0.1135  decode.acc_seg: 94.8853  aux.loss_ce: 0.0447  aux.acc_seg: 93.9209
# 06/26 21:32:07 - mmengine - INFO - per class results:
# 06/26 21:32:07 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 86.33 | 94.42 | 92.66 | 92.66  |   90.97   | 94.42  |
# |    red     | 87.38 | 91.67 | 93.26 | 93.26  |   94.91   | 91.67  |
# |   green    | 44.08 |  58.6 | 61.19 | 61.19  |   64.01   |  58.6  |
# |   white    | 75.37 | 80.94 | 85.95 | 85.95  |   91.62   | 80.94  |
# | seed-black | 60.28 | 85.44 | 75.22 | 75.22  |   67.19   | 85.44  |
# | seed-white | 26.56 | 29.48 | 41.98 | 41.98  |   72.86   | 29.48  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:32:07 - mmengine - INFO - Iter(val) [11/11]    aAcc: 90.1400  mIoU: 63.3300  mAcc: 73.4300  mDice: 75.0400  mFscore: 75.0400  mPrecision: 80.2600  mRecall: 73.4300  data_time: 0.0079  time: 0.1010
# 06/26 21:32:07 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet/best_mIoU_iter_2500.pth is removed
# 06/26 21:32:08 - mmengine - INFO - The best checkpoint with 63.3300 mIoU at 4000 iter is saved to best_mIoU_iter_4000.pth.
# 06/26 21:32:18 - mmengine - INFO - Iter(train) [ 4100/40000]  lr: 9.0821e-03  eta: 0:48:58  time: 0.0577  data_time: 0.0055  memory: 1707  loss: 0.1078  decode.loss_ce: 0.0750  decode.acc_seg: 96.8994  aux.loss_ce: 0.0328  aux.acc_seg: 96.8140
# 06/26 21:32:27 - mmengine - INFO - Iter(train) [ 4200/40000]  lr: 9.0595e-03  eta: 0:48:52  time: 0.0943  data_time: 0.0412  memory: 1253  loss: 0.1731  decode.loss_ce: 0.1215  decode.acc_seg: 93.9026  aux.loss_ce: 0.0515  aux.acc_seg: 89.6912
# 06/26 21:32:35 - mmengine - INFO - Iter(train) [ 4300/40000]  lr: 9.0370e-03  eta: 0:48:42  time: 0.0792  data_time: 0.0257  memory: 1253  loss: 0.1908  decode.loss_ce: 0.1365  decode.acc_seg: 68.9392  aux.loss_ce: 0.0544  aux.acc_seg: 67.1143
# 06/26 21:32:42 - mmengine - INFO - Iter(train) [ 4400/40000]  lr: 9.0145e-03  eta: 0:48:30  time: 0.0606  data_time: 0.0072  memory: 1253  loss: 0.1180  decode.loss_ce: 0.0849  decode.acc_seg: 92.1631  aux.loss_ce: 0.0331  aux.acc_seg: 91.9495
# 06/26 21:32:50 - mmengine - INFO - Iter(train) [ 4500/40000]  lr: 8.9919e-03  eta: 0:48:16  time: 0.0714  data_time: 0.0182  memory: 1253  loss: 0.1488  decode.loss_ce: 0.1058  decode.acc_seg: 69.1345  aux.loss_ce: 0.0430  aux.acc_seg: 70.4834
# 06/26 21:32:51 - mmengine - INFO - per class results:
# 06/26 21:32:51 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 86.79 | 96.18 | 92.93 | 92.93  |   89.89   | 96.18  |
# |    red     | 88.51 | 95.02 | 93.91 | 93.91  |   92.82   | 95.02  |
# |   green    | 18.35 | 18.51 | 31.01 | 31.01  |   95.47   | 18.51  |
# |   white    | 75.53 | 90.71 | 86.06 | 86.06  |   81.86   | 90.71  |
# | seed-black | 34.45 | 59.03 | 51.24 | 51.24  |   45.27   | 59.03  |
# | seed-white | 11.26 | 11.91 | 20.24 | 20.24  |   67.51   | 11.91  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:32:51 - mmengine - INFO - Iter(val) [11/11]    aAcc: 89.8100  mIoU: 52.4800  mAcc: 61.8900  mDice: 62.5600  mFscore: 62.5600  mPrecision: 78.8000  mRecall: 61.8900  data_time: 0.0090  time: 0.1016
# 06/26 21:32:59 - mmengine - INFO - Iter(train) [ 4600/40000]  lr: 8.9694e-03  eta: 0:48:08  time: 0.0776  data_time: 0.0247  memory: 1707  loss: 0.1762  decode.loss_ce: 0.1250  decode.acc_seg: 93.6584  aux.loss_ce: 0.0512  aux.acc_seg: 96.4111
# 06/26 21:33:07 - mmengine - INFO - Iter(train) [ 4700/40000]  lr: 8.9468e-03  eta: 0:47:58  time: 0.0624  data_time: 0.0070  memory: 1253  loss: 0.1257  decode.loss_ce: 0.0904  decode.acc_seg: 89.2212  aux.loss_ce: 0.0353  aux.acc_seg: 88.1836
# 06/26 21:33:15 - mmengine - INFO - Iter(train) [ 4800/40000]  lr: 8.9243e-03  eta: 0:47:50  time: 0.0588  data_time: 0.0059  memory: 1253  loss: 0.1852  decode.loss_ce: 0.1335  decode.acc_seg: 90.8752  aux.loss_ce: 0.0517  aux.acc_seg: 90.9729
# 06/26 21:33:23 - mmengine - INFO - Iter(train) [ 4900/40000]  lr: 8.9017e-03  eta: 0:47:40  time: 0.0814  data_time: 0.0302  memory: 1253  loss: 0.1654  decode.loss_ce: 0.1190  decode.acc_seg: 79.2358  aux.loss_ce: 0.0463  aux.acc_seg: 79.6509
# 06/26 21:33:31 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:33:31 - mmengine - INFO - Iter(train) [ 5000/40000]  lr: 8.8791e-03  eta: 0:47:30  time: 0.0878  data_time: 0.0266  memory: 1253  loss: 0.1844  decode.loss_ce: 0.1318  decode.acc_seg: 83.1665  aux.loss_ce: 0.0527  aux.acc_seg: 82.9285
# 06/26 21:33:31 - mmengine - INFO - Saving checkpoint at 5000 iterations
# 06/26 21:33:34 - mmengine - INFO - per class results:
# 06/26 21:33:34 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 83.63 | 91.85 | 91.08 | 91.08  |   90.33   | 91.85  |
# |    red     | 82.51 | 98.85 | 90.42 | 90.42  |   83.31   | 98.85  |
# |   green    | 19.85 |  20.4 | 33.12 | 33.12  |    87.9   |  20.4  |
# |   white    | 71.04 | 79.34 | 83.07 | 83.07  |   87.15   | 79.34  |
# | seed-black | 36.85 | 54.06 | 53.85 | 53.85  |   53.65   | 54.06  |
# | seed-white | 11.63 | 15.81 | 20.83 | 20.83  |   30.51   | 15.81  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:33:34 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.6100  mIoU: 50.9200  mAcc: 60.0500  mDice: 62.0600  mFscore: 62.0600  mPrecision: 72.1400  mRecall: 60.0500  data_time: 0.0096  time: 0.1032
# 06/26 21:33:42 - mmengine - INFO - Iter(train) [ 5100/40000]  lr: 8.8566e-03  eta: 0:47:18  time: 0.0846  data_time: 0.0370  memory: 1707  loss: 0.1859  decode.loss_ce: 0.1338  decode.acc_seg: 82.2083  aux.loss_ce: 0.0520  aux.acc_seg: 78.5583
# 06/26 21:33:50 - mmengine - INFO - Iter(train) [ 5200/40000]  lr: 8.8340e-03  eta: 0:47:11  time: 0.0754  data_time: 0.0229  memory: 1253  loss: 0.1589  decode.loss_ce: 0.1118  decode.acc_seg: 77.0081  aux.loss_ce: 0.0470  aux.acc_seg: 76.0681
# 06/26 21:33:58 - mmengine - INFO - Iter(train) [ 5300/40000]  lr: 8.8114e-03  eta: 0:46:58  time: 0.0602  data_time: 0.0073  memory: 1253  loss: 0.1309  decode.loss_ce: 0.0925  decode.acc_seg: 81.7627  aux.loss_ce: 0.0384  aux.acc_seg: 79.5471
# 06/26 21:34:06 - mmengine - INFO - Iter(train) [ 5400/40000]  lr: 8.7888e-03  eta: 0:46:51  time: 0.0834  data_time: 0.0255  memory: 1253  loss: 0.1454  decode.loss_ce: 0.1031  decode.acc_seg: 87.4146  aux.loss_ce: 0.0423  aux.acc_seg: 83.3008
# 06/26 21:34:14 - mmengine - INFO - Iter(train) [ 5500/40000]  lr: 8.7662e-03  eta: 0:46:41  time: 0.0729  data_time: 0.0067  memory: 1253  loss: 0.1264  decode.loss_ce: 0.0911  decode.acc_seg: 93.6340  aux.loss_ce: 0.0353  aux.acc_seg: 94.9890
# 06/26 21:34:15 - mmengine - INFO - per class results:
# 06/26 21:34:15 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  82.3 | 92.17 | 90.29 | 90.29  |   88.49   | 92.17  |
# |    red     | 84.23 | 97.13 | 91.44 | 91.44  |   86.38   | 97.13  |
# |   green    |  10.0 | 10.03 | 18.17 | 18.17  |   96.52   | 10.03  |
# |   white    | 68.17 |  83.5 | 81.07 | 81.07  |   78.78   |  83.5  |
# | seed-black | 52.46 | 63.55 | 68.82 | 68.82  |   75.04   | 63.55  |
# | seed-white |  31.9 | 54.35 | 48.37 | 48.37  |   43.58   | 54.35  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:34:15 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.0400  mIoU: 54.8400  mAcc: 66.7900  mDice: 66.3600  mFscore: 66.3600  mPrecision: 78.1300  mRecall: 66.7900  data_time: 0.0093  time: 0.1016
# 06/26 21:34:23 - mmengine - INFO - Iter(train) [ 5600/40000]  lr: 8.7436e-03  eta: 0:46:30  time: 0.0792  data_time: 0.0264  memory: 1707  loss: 0.1868  decode.loss_ce: 0.1335  decode.acc_seg: 93.5120  aux.loss_ce: 0.0533  aux.acc_seg: 89.5081
# 06/26 21:34:30 - mmengine - INFO - Iter(train) [ 5700/40000]  lr: 8.7210e-03  eta: 0:46:19  time: 0.0595  data_time: 0.0064  memory: 1253  loss: 0.1610  decode.loss_ce: 0.1149  decode.acc_seg: 94.6472  aux.loss_ce: 0.0461  aux.acc_seg: 94.6106
# 06/26 21:34:38 - mmengine - INFO - Iter(train) [ 5800/40000]  lr: 8.6983e-03  eta: 0:46:09  time: 0.0808  data_time: 0.0291  memory: 1253  loss: 0.1739  decode.loss_ce: 0.1223  decode.acc_seg: 95.2332  aux.loss_ce: 0.0517  aux.acc_seg: 93.0054
# 06/26 21:34:46 - mmengine - INFO - Iter(train) [ 5900/40000]  lr: 8.6757e-03  eta: 0:45:59  time: 0.0771  data_time: 0.0285  memory: 1253  loss: 0.1668  decode.loss_ce: 0.1192  decode.acc_seg: 69.4336  aux.loss_ce: 0.0477  aux.acc_seg: 74.7375
# 06/26 21:34:53 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:34:53 - mmengine - INFO - Iter(train) [ 6000/40000]  lr: 8.6531e-03  eta: 0:45:48  time: 0.0583  data_time: 0.0054  memory: 1253  loss: 0.2121  decode.loss_ce: 0.1539  decode.acc_seg: 96.3257  aux.loss_ce: 0.0582  aux.acc_seg: 95.3613
# 06/26 21:34:54 - mmengine - INFO - per class results:
# 06/26 21:34:55 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 87.22 | 95.24 | 93.17 | 93.17  |   91.19   | 95.24  |
# |    red     | 89.73 | 96.48 | 94.59 | 94.59  |   92.76   | 96.48  |
# |   green    | 26.98 | 27.25 | 42.49 | 42.49  |   96.38   | 27.25  |
# |   white    | 69.47 | 89.87 | 81.98 | 81.98  |   75.37   | 89.87  |
# | seed-black | 57.12 | 73.84 | 72.71 | 72.71  |   71.61   | 73.84  |
# | seed-white | 27.43 | 30.54 | 43.05 | 43.05  |    72.9   | 30.54  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:34:55 - mmengine - INFO - Iter(val) [11/11]    aAcc: 90.3100  mIoU: 59.6600  mAcc: 68.8700  mDice: 71.3300  mFscore: 71.3300  mPrecision: 83.3700  mRecall: 68.8700  data_time: 0.0068  time: 0.1012
# 06/26 21:35:03 - mmengine - INFO - Iter(train) [ 6100/40000]  lr: 8.6304e-03  eta: 0:45:40  time: 0.0796  data_time: 0.0254  memory: 1707  loss: 0.1337  decode.loss_ce: 0.0940  decode.acc_seg: 90.6128  aux.loss_ce: 0.0397  aux.acc_seg: 88.0615
# 06/26 21:35:10 - mmengine - INFO - Iter(train) [ 6200/40000]  lr: 8.6078e-03  eta: 0:45:31  time: 0.0773  data_time: 0.0229  memory: 1253  loss: 0.1224  decode.loss_ce: 0.0860  decode.acc_seg: 89.3860  aux.loss_ce: 0.0364  aux.acc_seg: 88.6658
# 06/26 21:35:18 - mmengine - INFO - Iter(train) [ 6300/40000]  lr: 8.5851e-03  eta: 0:45:21  time: 0.0796  data_time: 0.0243  memory: 1253  loss: 0.2064  decode.loss_ce: 0.1456  decode.acc_seg: 82.1533  aux.loss_ce: 0.0608  aux.acc_seg: 82.5562
# 06/26 21:35:26 - mmengine - INFO - Iter(train) [ 6400/40000]  lr: 8.5625e-03  eta: 0:45:11  time: 0.0604  data_time: 0.0060  memory: 1253  loss: 0.1621  decode.loss_ce: 0.1158  decode.acc_seg: 68.0603  aux.loss_ce: 0.0463  aux.acc_seg: 65.8691
# 06/26 21:35:34 - mmengine - INFO - Iter(train) [ 6500/40000]  lr: 8.5398e-03  eta: 0:45:02  time: 0.0648  data_time: 0.0064  memory: 1253  loss: 0.1695  decode.loss_ce: 0.1213  decode.acc_seg: 87.0056  aux.loss_ce: 0.0482  aux.acc_seg: 86.3770
# 06/26 21:35:35 - mmengine - INFO - per class results:
# 06/26 21:35:35 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 86.17 | 94.34 | 92.57 | 92.57  |   90.88   | 94.34  |
# |    red     | 86.84 | 95.71 | 92.96 | 92.96  |   90.36   | 95.71  |
# |   green    | 32.38 | 36.62 | 48.92 | 48.92  |   73.67   | 36.62  |
# |   white    | 73.51 | 83.03 | 84.74 | 84.74  |   86.51   | 83.03  |
# | seed-black | 47.16 | 67.43 |  64.1 |  64.1  |   61.08   | 67.43  |
# | seed-white | 12.33 |  12.4 | 21.95 | 21.95  |   95.72   |  12.4  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:35:35 - mmengine - INFO - Iter(val) [11/11]    aAcc: 89.6700  mIoU: 56.4000  mAcc: 64.9200  mDice: 67.5400  mFscore: 67.5400  mPrecision: 83.0400  mRecall: 64.9200  data_time: 0.0075  time: 0.1008
# 06/26 21:35:43 - mmengine - INFO - Iter(train) [ 6600/40000]  lr: 8.5171e-03  eta: 0:44:53  time: 0.0858  data_time: 0.0327  memory: 1707  loss: 0.1934  decode.loss_ce: 0.1359  decode.acc_seg: 87.0239  aux.loss_ce: 0.0576  aux.acc_seg: 88.1531
# 06/26 21:35:51 - mmengine - INFO - Iter(train) [ 6700/40000]  lr: 8.4944e-03  eta: 0:44:43  time: 0.0536  data_time: 0.0059  memory: 1253  loss: 0.1420  decode.loss_ce: 0.1004  decode.acc_seg: 80.6885  aux.loss_ce: 0.0416  aux.acc_seg: 78.8208
# 06/26 21:35:59 - mmengine - INFO - Iter(train) [ 6800/40000]  lr: 8.4717e-03  eta: 0:44:36  time: 0.0835  data_time: 0.0303  memory: 1253  loss: 0.1648  decode.loss_ce: 0.1176  decode.acc_seg: 47.0215  aux.loss_ce: 0.0471  aux.acc_seg: 46.5759
# 06/26 21:36:07 - mmengine - INFO - Iter(train) [ 6900/40000]  lr: 8.4490e-03  eta: 0:44:27  time: 0.0914  data_time: 0.0440  memory: 1253  loss: 0.1824  decode.loss_ce: 0.1293  decode.acc_seg: 69.0613  aux.loss_ce: 0.0531  aux.acc_seg: 70.2271
# 06/26 21:36:15 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:36:15 - mmengine - INFO - Iter(train) [ 7000/40000]  lr: 8.4263e-03  eta: 0:44:19  time: 0.0863  data_time: 0.0333  memory: 1253  loss: 0.2056  decode.loss_ce: 0.1457  decode.acc_seg: 95.8008  aux.loss_ce: 0.0598  aux.acc_seg: 95.3064
# 06/26 21:36:16 - mmengine - INFO - per class results:
# 06/26 21:36:16 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.81 | 91.47 | 92.36 | 92.36  |   93.27   | 91.47  |
# |    red     | 88.91 | 95.19 | 94.13 | 94.13  |   93.09   | 95.19  |
# |   green    | 34.39 | 47.49 | 51.18 | 51.18  |    55.5   | 47.49  |
# |   white    |  66.6 | 89.81 | 79.95 | 79.95  |   72.04   | 89.81  |
# | seed-black | 55.28 | 58.96 |  71.2 |  71.2  |   89.85   | 58.96  |
# | seed-white | 32.15 | 54.03 | 48.65 | 48.65  |   44.25   | 54.03  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:36:16 - mmengine - INFO - Iter(val) [11/11]    aAcc: 89.0800  mIoU: 60.5200  mAcc: 72.8200  mDice: 72.9100  mFscore: 72.9100  mPrecision: 74.6700  mRecall: 72.8200  data_time: 0.0095  time: 0.1025
# 06/26 21:36:23 - mmengine - INFO - Iter(train) [ 7100/40000]  lr: 8.4036e-03  eta: 0:44:08  time: 0.0810  data_time: 0.0331  memory: 1707  loss: 0.1882  decode.loss_ce: 0.1328  decode.acc_seg: 79.1077  aux.loss_ce: 0.0555  aux.acc_seg: 75.5676
# 06/26 21:36:31 - mmengine - INFO - Iter(train) [ 7200/40000]  lr: 8.3809e-03  eta: 0:43:58  time: 0.0763  data_time: 0.0235  memory: 1253  loss: 0.1129  decode.loss_ce: 0.0788  decode.acc_seg: 79.0955  aux.loss_ce: 0.0341  aux.acc_seg: 77.2034
# 06/26 21:36:39 - mmengine - INFO - Iter(train) [ 7300/40000]  lr: 8.3582e-03  eta: 0:43:49  time: 0.0584  data_time: 0.0050  memory: 1253  loss: 0.1609  decode.loss_ce: 0.1146  decode.acc_seg: 91.1499  aux.loss_ce: 0.0463  aux.acc_seg: 91.2354
# 06/26 21:36:47 - mmengine - INFO - Iter(train) [ 7400/40000]  lr: 8.3354e-03  eta: 0:43:41  time: 0.0786  data_time: 0.0251  memory: 1253  loss: 0.1252  decode.loss_ce: 0.0895  decode.acc_seg: 90.3320  aux.loss_ce: 0.0357  aux.acc_seg: 89.4836
# 06/26 21:36:54 - mmengine - INFO - Iter(train) [ 7500/40000]  lr: 8.3127e-03  eta: 0:43:31  time: 0.0798  data_time: 0.0232  memory: 1253  loss: 0.1479  decode.loss_ce: 0.1073  decode.acc_seg: 75.8911  aux.loss_ce: 0.0406  aux.acc_seg: 75.7812
# 06/26 21:36:54 - mmengine - INFO - Saving checkpoint at 7500 iterations
# 06/26 21:36:58 - mmengine - INFO - per class results:
# 06/26 21:36:58 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  86.4 |  93.9 |  92.7 |  92.7  |   91.54   |  93.9  |
# |    red     | 89.46 | 97.15 | 94.43 | 94.43  |   91.87   | 97.15  |
# |   green    | 24.05 |  28.8 | 38.77 | 38.77  |    59.3   |  28.8  |
# |   white    | 61.78 | 79.53 | 76.37 | 76.37  |   73.46   | 79.53  |
# | seed-black | 57.43 | 74.24 | 72.96 | 72.96  |   71.72   | 74.24  |
# | seed-white |  6.38 |  8.5  |  12.0 |  12.0  |   20.37   |  8.5   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:36:58 - mmengine - INFO - Iter(val) [11/11]    aAcc: 89.0500  mIoU: 54.2500  mAcc: 63.6900  mDice: 64.5400  mFscore: 64.5400  mPrecision: 68.0400  mRecall: 63.6900  data_time: 0.0094  time: 0.1025
# 06/26 21:37:07 - mmengine - INFO - Iter(train) [ 7600/40000]  lr: 8.2900e-03  eta: 0:43:25  time: 0.0874  data_time: 0.0281  memory: 1707  loss: 0.1284  decode.loss_ce: 0.0902  decode.acc_seg: 84.5276  aux.loss_ce: 0.0382  aux.acc_seg: 85.9619
# 06/26 21:37:15 - mmengine - INFO - Iter(train) [ 7700/40000]  lr: 8.2672e-03  eta: 0:43:18  time: 0.0587  data_time: 0.0062  memory: 1253  loss: 0.1264  decode.loss_ce: 0.0896  decode.acc_seg: 89.5447  aux.loss_ce: 0.0369  aux.acc_seg: 90.3015
# 06/26 21:37:23 - mmengine - INFO - Iter(train) [ 7800/40000]  lr: 8.2444e-03  eta: 0:43:11  time: 0.1196  data_time: 0.0679  memory: 1253  loss: 0.1525  decode.loss_ce: 0.1083  decode.acc_seg: 90.9302  aux.loss_ce: 0.0442  aux.acc_seg: 85.4675
# 06/26 21:37:32 - mmengine - INFO - Iter(train) [ 7900/40000]  lr: 8.2217e-03  eta: 0:43:04  time: 0.0766  data_time: 0.0241  memory: 1253  loss: 0.1477  decode.loss_ce: 0.1051  decode.acc_seg: 74.7864  aux.loss_ce: 0.0426  aux.acc_seg: 75.1099
# 06/26 21:37:39 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:37:39 - mmengine - INFO - Iter(train) [ 8000/40000]  lr: 8.1989e-03  eta: 0:42:55  time: 0.0980  data_time: 0.0443  memory: 1253  loss: 0.1756  decode.loss_ce: 0.1271  decode.acc_seg: 91.0889  aux.loss_ce: 0.0485  aux.acc_seg: 92.6758
# 06/26 21:37:41 - mmengine - INFO - per class results:
# 06/26 21:37:41 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 87.85 | 95.18 | 93.53 | 93.53  |   91.94   | 95.18  |
# |    red     | 89.69 | 97.83 | 94.57 | 94.57  |   91.52   | 97.83  |
# |   green    | 26.17 | 26.98 | 41.49 | 41.49  |   89.74   | 26.98  |
# |   white    | 76.03 | 92.74 | 86.38 | 86.38  |   80.84   | 92.74  |
# | seed-black | 50.47 | 66.79 | 67.08 | 67.08  |   67.38   | 66.79  |
# | seed-white | 19.96 |  21.9 | 33.28 | 33.28  |   69.31   |  21.9  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:37:41 - mmengine - INFO - Iter(val) [11/11]    aAcc: 90.7500  mIoU: 58.3600  mAcc: 66.9000  mDice: 69.3900  mFscore: 69.3900  mPrecision: 81.7900  mRecall: 66.9000  data_time: 0.0082  time: 0.1012
# 06/26 21:37:49 - mmengine - INFO - Iter(train) [ 8100/40000]  lr: 8.1761e-03  eta: 0:42:47  time: 0.0772  data_time: 0.0235  memory: 1707  loss: 0.1566  decode.loss_ce: 0.1111  decode.acc_seg: 92.3950  aux.loss_ce: 0.0455  aux.acc_seg: 94.6838
# 06/26 21:37:57 - mmengine - INFO - Iter(train) [ 8200/40000]  lr: 8.1533e-03  eta: 0:42:39  time: 0.0802  data_time: 0.0258  memory: 1253  loss: 0.1498  decode.loss_ce: 0.1076  decode.acc_seg: 86.6089  aux.loss_ce: 0.0422  aux.acc_seg: 85.3455
# 06/26 21:38:04 - mmengine - INFO - Iter(train) [ 8300/40000]  lr: 8.1305e-03  eta: 0:42:30  time: 0.0596  data_time: 0.0064  memory: 1253  loss: 0.1011  decode.loss_ce: 0.0702  decode.acc_seg: 97.7783  aux.loss_ce: 0.0309  aux.acc_seg: 97.8577
# 06/26 21:38:12 - mmengine - INFO - Iter(train) [ 8400/40000]  lr: 8.1077e-03  eta: 0:42:21  time: 0.0893  data_time: 0.0356  memory: 1253  loss: 0.1316  decode.loss_ce: 0.0917  decode.acc_seg: 84.5825  aux.loss_ce: 0.0399  aux.acc_seg: 83.1543
# 06/26 21:38:20 - mmengine - INFO - Iter(train) [ 8500/40000]  lr: 8.0849e-03  eta: 0:42:11  time: 0.0761  data_time: 0.0220  memory: 1253  loss: 0.1495  decode.loss_ce: 0.1056  decode.acc_seg: 69.1040  aux.loss_ce: 0.0439  aux.acc_seg: 70.8435
# 06/26 21:38:21 - mmengine - INFO - per class results:
# 06/26 21:38:21 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 80.96 | 83.56 | 89.48 | 89.48  |    96.3   | 83.56  |
# |    red     | 84.15 | 98.24 | 91.39 | 91.39  |   85.44   | 98.24  |
# |   green    | 46.89 | 73.69 | 63.84 | 63.84  |   56.31   | 73.69  |
# |   white    | 65.96 | 91.21 | 79.49 | 79.49  |   70.44   | 91.21  |
# | seed-black | 45.42 | 52.23 | 62.47 | 62.47  |   77.71   | 52.23  |
# | seed-white | 28.04 | 30.02 | 43.79 | 43.79  |    80.9   | 30.02  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:38:21 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.0300  mIoU: 58.5700  mAcc: 71.4900  mDice: 71.7400  mFscore: 71.7400  mPrecision: 77.8500  mRecall: 71.4900  data_time: 0.0075  time: 0.0999
# 06/26 21:38:29 - mmengine - INFO - Iter(train) [ 8600/40000]  lr: 8.0621e-03  eta: 0:42:02  time: 0.0690  data_time: 0.0142  memory: 1707  loss: 0.1932  decode.loss_ce: 0.1398  decode.acc_seg: 61.6516  aux.loss_ce: 0.0534  aux.acc_seg: 62.3352
# 06/26 21:38:36 - mmengine - INFO - Iter(train) [ 8700/40000]  lr: 8.0393e-03  eta: 0:41:53  time: 0.0595  data_time: 0.0054  memory: 1253  loss: 0.1907  decode.loss_ce: 0.1378  decode.acc_seg: 81.1707  aux.loss_ce: 0.0529  aux.acc_seg: 80.4810
# 06/26 21:38:44 - mmengine - INFO - Iter(train) [ 8800/40000]  lr: 8.0164e-03  eta: 0:41:44  time: 0.0784  data_time: 0.0242  memory: 1253  loss: 0.1870  decode.loss_ce: 0.1350  decode.acc_seg: 69.6716  aux.loss_ce: 0.0520  aux.acc_seg: 69.3726
# 06/26 21:38:52 - mmengine - INFO - Iter(train) [ 8900/40000]  lr: 7.9936e-03  eta: 0:41:35  time: 0.0830  data_time: 0.0302  memory: 1253  loss: 0.1296  decode.loss_ce: 0.0919  decode.acc_seg: 80.1575  aux.loss_ce: 0.0377  aux.acc_seg: 82.9163
# 06/26 21:39:00 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:39:00 - mmengine - INFO - Iter(train) [ 9000/40000]  lr: 7.9708e-03  eta: 0:41:26  time: 0.0878  data_time: 0.0359  memory: 1253  loss: 0.1089  decode.loss_ce: 0.0772  decode.acc_seg: 80.9631  aux.loss_ce: 0.0317  aux.acc_seg: 85.0464
# 06/26 21:39:01 - mmengine - INFO - per class results:
# 06/26 21:39:01 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.39 | 88.74 | 92.12 | 92.12  |   95.76   | 88.74  |
# |    red     | 90.27 | 97.75 | 94.89 | 94.89  |   92.19   | 97.75  |
# |   green    | 46.15 | 72.32 | 63.16 | 63.16  |   56.05   | 72.32  |
# |   white    |  71.9 | 88.47 | 83.65 | 83.65  |   79.33   | 88.47  |
# | seed-black | 42.53 | 62.07 | 59.68 | 59.68  |   57.47   | 62.07  |
# | seed-white | 26.86 | 31.11 | 42.35 | 42.35  |   66.32   | 31.11  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:39:01 - mmengine - INFO - Iter(val) [11/11]    aAcc: 89.7300  mIoU: 60.5200  mAcc: 73.4100  mDice: 72.6400  mFscore: 72.6400  mPrecision: 74.5200  mRecall: 73.4100  data_time: 0.0105  time: 0.1024
# 06/26 21:39:09 - mmengine - INFO - Iter(train) [ 9100/40000]  lr: 7.9479e-03  eta: 0:41:17  time: 0.0870  data_time: 0.0319  memory: 1707  loss: 0.1555  decode.loss_ce: 0.1108  decode.acc_seg: 85.1013  aux.loss_ce: 0.0447  aux.acc_seg: 90.1794
# 06/26 21:39:17 - mmengine - INFO - Iter(train) [ 9200/40000]  lr: 7.9250e-03  eta: 0:41:09  time: 0.0905  data_time: 0.0354  memory: 1253  loss: 0.1459  decode.loss_ce: 0.1029  decode.acc_seg: 75.3235  aux.loss_ce: 0.0429  aux.acc_seg: 77.1484
# 06/26 21:39:24 - mmengine - INFO - Iter(train) [ 9300/40000]  lr: 7.9022e-03  eta: 0:41:00  time: 0.0755  data_time: 0.0241  memory: 1253  loss: 0.2140  decode.loss_ce: 0.1540  decode.acc_seg: 85.1868  aux.loss_ce: 0.0600  aux.acc_seg: 84.5764
# 06/26 21:39:32 - mmengine - INFO - Iter(train) [ 9400/40000]  lr: 7.8793e-03  eta: 0:40:52  time: 0.0901  data_time: 0.0307  memory: 1253  loss: 0.1881  decode.loss_ce: 0.1334  decode.acc_seg: 96.5820  aux.loss_ce: 0.0547  aux.acc_seg: 96.1609
# 06/26 21:39:40 - mmengine - INFO - Iter(train) [ 9500/40000]  lr: 7.8564e-03  eta: 0:40:42  time: 0.0783  data_time: 0.0227  memory: 1253  loss: 0.1720  decode.loss_ce: 0.1214  decode.acc_seg: 89.2883  aux.loss_ce: 0.0506  aux.acc_seg: 86.8225
# 06/26 21:39:41 - mmengine - INFO - per class results:
# 06/26 21:39:41 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 87.28 | 90.93 | 93.21 | 93.21  |    95.6   | 90.93  |
# |    red     | 91.28 | 95.95 | 95.44 | 95.44  |   94.94   | 95.95  |
# |   green    | 44.97 |  66.6 | 62.04 | 62.04  |   58.06   |  66.6  |
# |   white    | 71.55 | 94.97 | 83.42 | 83.42  |   74.37   | 94.97  |
# | seed-black | 54.73 | 57.77 | 70.74 | 70.74  |   91.24   | 57.77  |
# | seed-white | 35.71 | 40.31 | 52.63 | 52.63  |   75.77   | 40.31  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 21:39:41 - mmengine - INFO - Iter(val) [11/11]    aAcc: 90.5900  mIoU: 64.2500  mAcc: 74.4200  mDice: 76.2500  mFscore: 76.2500  mPrecision: 81.6600  mRecall: 74.4200  data_time: 0.0094  time: 0.1028
# 06/26 21:39:41 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet/best_mIoU_iter_4000.pth is removed
# 06/26 21:39:43 - mmengine - INFO - The best checkpoint with 64.2500 mIoU at 9500 iter is saved to best_mIoU_iter_9500.pth.
# 06/26 21:39:53 - mmengine - INFO - Iter(train) [ 9600/40000]  lr: 7.8335e-03  eta: 0:40:47  time: 0.0802  data_time: 0.0281  memory: 1707  loss: 0.1323  decode.loss_ce: 0.0937  decode.acc_seg: 87.3230  aux.loss_ce: 0.0386  aux.acc_seg: 84.8083
# 06/26 21:40:01 - mmengine - INFO - Iter(train) [ 9700/40000]  lr: 7.8106e-03  eta: 0:40:38  time: 0.0842  data_time: 0.0303  memory: 1253  loss: 0.1599  decode.loss_ce: 0.1132  decode.acc_seg: 83.2642  aux.loss_ce: 0.0466  aux.acc_seg: 82.4402
# 06/26 21:40:09 - mmengine - INFO - Iter(train) [ 9800/40000]  lr: 7.7877e-03  eta: 0:40:31  time: 0.0582  data_time: 0.0058  memory: 1253  loss: 0.1509  decode.loss_ce: 0.1091  decode.acc_seg: 87.8479  aux.loss_ce: 0.0418  aux.acc_seg: 90.5273
# 06/26 21:40:17 - mmengine - INFO - Iter(train) [ 9900/40000]  lr: 7.7648e-03  eta: 0:40:22  time: 0.0863  data_time: 0.0317  memory: 1253  loss: 0.1028  decode.loss_ce: 0.0725  decode.acc_seg: 99.8352  aux.loss_ce: 0.0303  aux.acc_seg: 99.7620
# 06/26 21:40:25 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 21:40:25 - mmengine - INFO - Iter(train) [10000/40000]  lr: 7.7419e-03  eta: 0:40:14  time: 0.1014  data_time: 0.0439  memory: 1253  loss: 0.1375  decode.loss_ce: 0.0968  decode.acc_seg: 70.5322  aux.loss_ce: 0.0407  aux.acc_seg: 68.8904
# 06/26 21:40:25 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 06/26 21:40:29 - mmengine - INFO - per class results:
# 06/26 21:40:29 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 87.43 | 91.66 |  93.3 |  93.3  |   94.99   | 91.66  |
# |    red     | 86.44 | 97.56 | 92.73 | 92.73  |   88.35   | 97.56  |
# |   green    | 55.55 | 59.51 | 71.42 | 71.42  |    89.3   | 59.51  |
# |   white    | 70.71 | 90.07 | 82.84 | 82.84  |   76.69   | 90.07  |
# ...
# 06/26 22:20:55 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230626_20230626_212605
# 06/26 22:20:55 - mmengine - INFO - Iter(train) [40000/40000]  lr: 1.0000e-04  eta: 0:00:00  time: 0.0770  data_time: 0.0227  memory: 1253  loss: 0.0762  decode.loss_ce: 0.0533  decode.acc_seg: 91.7236  aux.loss_ce: 0.0229  aux.acc_seg: 90.6006
# 06/26 22:20:55 - mmengine - INFO - Saving checkpoint at 40000 iterations
# 06/26 22:20:59 - mmengine - INFO - per class results:
# 06/26 22:20:59 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 92.36 | 93.73 | 96.03 | 96.03  |   98.44   | 93.73  |
# |    red     | 92.58 | 97.52 | 96.15 | 96.15  |   94.82   | 97.52  |
# |   green    | 69.81 | 89.26 | 82.22 | 82.22  |   76.22   | 89.26  |
# |   white    | 81.46 | 95.35 | 89.78 | 89.78  |   84.83   | 95.35  |
# | seed-black | 46.91 | 67.85 | 63.87 | 63.87  |   60.33   | 67.85  |
# | seed-white |  40.8 | 53.65 | 57.95 | 57.95  |    63.0   | 53.65  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/26 22:20:59 - mmengine - INFO - Iter(val) [11/11]    aAcc: 94.3200  mIoU: 70.6500  mAcc: 82.8900  mDice: 81.0000  mFscore: 81.0000  mPrecision: 79.6100  mRecall: 82.8900  data_time: 0.0079  time: 0.1011
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 6, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %% [markdown]
# ## 训练结果保存至`work_dirs`目录
