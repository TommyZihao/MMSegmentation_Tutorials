# %% [markdown]
# ### Add a new dataset
#
# Datasets in MMSegmentation require image and semantic segmentation maps to be placed in folders with the same prefix. To support a new dataset, we may need to modify the original file structure.
#
# In this tutorial, we give an example of converting the dataset. You may refer to [docs](https://github.com/open-mmlab/mmsegmentation/blob/master/docs/en/tutorials/customize_datasets.md#customize-datasets-by-reorganizing-data) for details about dataset reorganization.
#
# We use [Stanford Background Dataset](http://dags.stanford.edu/projects/scenedataset.html) as an example. The dataset contains 715 images chosen from existing public datasets [LabelMe](http://labelme.csail.mit.edu), [MSRC](http://research.microsoft.com/en-us/projects/objectclassrecognition), [PASCAL VOC](http://pascallin.ecs.soton.ac.uk/challenges/VOC) and [Geometric Context](http://www.cs.illinois.edu/homes/dhoiem/). Images from these datasets are mainly outdoor scenes, each containing approximately 320-by-240 pixels.
# In this tutorial, we use the region annotations as labels. There are 8 classes in total, i.e. sky, tree, road, grass, water, building, mountain, and foreground object.

# %% [markdown]
# ## 进入 mmsegmentation 主目录

# %%
import os
os.chdir('mmsegmentation')

# %% [markdown]
# ## 导入工具包

# %%
import numpy as np
from PIL import Image

import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 下载数据集

# %% [markdown]
# Standord Background 数据集主页：http://dags.stanford.edu/projects/scenedataset.html
#
# 该数据集包含 715 张由 [LabelMe](http://labelme.csail.mit.edu), [MSRC](http://research.microsoft.com/en-us/projects/objectclassrecognition), [PASCAL VOC](http://pascallin.ecs.soton.ac.uk/challenges/VOC) 和 [Geometric Context](http://www.cs.illinois.edu/homes/dhoiem/) 四个开源数据集中挑选出来的图片。
#
# 主要为室外场景，图像尺寸为320x240。
#
# 共 8 个类别：
#
# - 天空 sky
#
# - 树 tree
#
# - 道路 road
#
# - 草 grass
#
# - 水 water
#
# - 建筑物 building
#
# - 山 mountain
#
# - 前景物体

# %%
# !wget http://dags.stanford.edu/data/iccv09Data.tar.gz -O stanford_background.tar.gz

# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/iccv09Data.tar.gz -O stanford_background.tar.gz
# Out:
# --2023-01-30 19:58:48--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20230130-mmseg/dataset/iccv09Data.tar.gz
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 14727974 (14M) [application/gzip]
# 正在保存至: “stanford_background.tar.gz”
#
# stanford_background 100%[===================>]  14.04M  27.8MB/s    用时 0.5s
#
# 2023-01-30 19:58:49 (27.8 MB/s) - 已保存 “stanford_background.tar.gz” [14727974/14727974])

# %% [markdown]
# ## 解压

# %%
# 删除旧的数据集文件夹（如有）
# !rm -rf iccv09Data

# %%
# !tar xf stanford_background.tar.gz

# %% [markdown]
# ## 查看数据集中的图片

# %%
Image.open('iccv09Data/images/6000124.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F030EE1C9D0>

# %% [markdown]
# ## 数据集图片和标注路径

# %%
data_root = 'iccv09Data'
img_dir = 'images'
ann_dir = 'labels'

# %% [markdown]
# ## 类别和对应的颜色

# %%
classes = ('sky', 'tree', 'road', 'grass', 'water', 'bldg', 'mntn', 'fg obj')
palette = [[128, 128, 128], [129, 127, 38], [120, 69, 125], [53, 125, 34], 
           [0, 11, 123], [118, 20, 12], [122, 81, 25], [241, 134, 51]]

# %% [markdown]
# ## 转换语义分割标注格式为 segmentation map 图片

# %%
for file in tqdm(mmengine.scandir(osp.join(data_root, ann_dir), suffix='.regions.txt')):
  seg_map = np.loadtxt(osp.join(data_root, ann_dir, file)).astype(np.uint8)
  seg_img = Image.fromarray(seg_map).convert('P')
  seg_img.putpalette(np.array(palette, dtype=np.uint8))
  seg_img.save(osp.join(data_root, ann_dir, file.replace('.regions.txt', 
                                                         '.png')))
# Out:
# 715it [00:25, 28.53it/s]

# %% [markdown]
# ## 查看 语义分割标注 Segmentation Map

# %%
Image.open('iccv09Data/labels/6000124.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=320x240 at 0x7F030EEA3490>

# %%
import matplotlib.patches as mpatches
img = Image.open('iccv09Data/labels/6000124.png')
plt.figure(figsize=(8, 6))
im = plt.imshow(np.array(img.convert('RGB')))

# 图例小块
patches = [mpatches.Patch(color=np.array(palette[i])/255., label=classes[i]) for i in range(8)]
# 图例
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='large')
plt.show()

# %% [markdown]
# ## 随机划分训练集和验证集

# %%
split_dir = 'splits'
mmengine.mkdir_or_exist(osp.join(data_root, split_dir))
filename_list = [osp.splitext(filename)[0] for filename in mmengine.scandir(
    osp.join(data_root, ann_dir), suffix='.png')]
with open(osp.join(data_root, split_dir, 'train.txt'), 'w') as f:
  # select first 4/5 as train set
  train_length = int(len(filename_list)*4/5)
  f.writelines(line + '\n' for line in filename_list[:train_length])
with open(osp.join(data_root, split_dir, 'val.txt'), 'w') as f:
  # select last 1/5 as train set
  f.writelines(line + '\n' for line in filename_list[train_length:])

# %% [markdown]
# After downloading the data, we need to implement `load_annotations` function in the new dataset class `StanfordBackgroundDataset`.

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset


@DATASETS.register_module()
class StanfordBackgroundDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.jpg', seg_map_suffix='.png', **kwargs)

# %% [markdown]
# ## 修改config配置文件

# %%
# 下载 config 文件 和 预训练模型checkpoint权重文件
# !mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .
# Out:
# processing pspnet_r50-d8_4xb2-40k_cityscapes-512x1024...
# pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth exists in /home/featurize/work/MMSegmentation教程/mmsegmentation
# Successfully dumped pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py to /home/featurize/work/MMSegmentation教程/mmsegmentation

# %%
from mmengine import Config
cfg = Config.fromfile('configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py')

# %%
cfg.norm_cfg = dict(type='BN', requires_grad=True) # 只使用GPU时，BN取代SyncBN
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# modify num classes of the model in decode/auxiliary head
cfg.model.decode_head.num_classes = 8
cfg.model.auxiliary_head.num_classes = 8

# 修改数据集的 type 和 root
cfg.dataset_type = 'StanfordBackgroundDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(320, 240), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(320, 240), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]


cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/train.txt'

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/val.txt'

cfg.test_dataloader = cfg.val_dataloader


# 载入预训练模型权重
cfg.load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'

# 工作目录
cfg.work_dir = './work_dirs/tutorial'

cfg.train_cfg.max_iters = 1200
cfg.train_cfg.val_interval = 400
cfg.default_hooks.logger.interval = 100
cfg.default_hooks.checkpoint.interval = 400

# 随机数种子
cfg['randomness'] = dict(seed=0)

# %% [markdown]
# ## 查看完整config配置文件

# %%
print(cfg.pretty_text)
# Out:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(512, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=8,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=8,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'StanfordBackgroundDataset'
# data_root = 'iccv09Data'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(320, 240),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(320, 240), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=8,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(320, 240),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/train.txt'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(320, 240), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/val.txt'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(320, 240), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/val.txt'))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=1200, val_interval=200)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=200),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# work_dir = './work_dirs/tutorial'
# randomness = dict(seed=0)

# %% [markdown]
# ## 准备训练

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 01/30 20:59:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3080
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.5.4
#     MMEngine: 0.5.0
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 01/30 20:59:07 - mmengine - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(512, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 2, 4),
#         strides=(1, 2, 1, 1),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     decode_head=dict(
#         type='PSPHead',
#         in_channels=2048,
#         in_index=3,
#         channels=512,
#         pool_scales=(1, 2, 3, 6),
#         dropout_ratio=0.1,
#         num_classes=8,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     auxiliary_head=dict(
#         type='FCNHead',
#         in_channels=1024,
#         in_index=2,
#         channels=256,
#         num_convs=1,
#         concat_input=False,
#         dropout_ratio=0.1,
#         num_classes=8,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=0.4)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# dataset_type = 'StanfordBackgroundDataset'
# data_root = 'iccv09Data'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(320, 240),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(320, 240), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=8,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(320, 240),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/train.txt'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(320, 240), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/val.txt'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='StanfordBackgroundDataset',
#         data_root='iccv09Data',
#         data_prefix=dict(img_path='images', seg_map_path='labels'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(320, 240), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ],
#         ann_file='splits/val.txt'))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=0,
#         end=40000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=1200, val_interval=200)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=200),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# work_dir = './work_dirs/tutorial'
# randomness = dict(seed=0)
#
# 01/30 20:59:07 - mmengine - WARNING - The "visualizer" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:07 - mmengine - WARNING - The "vis_backend" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:08 - mmengine - WARNING - The "model" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# /home/featurize/work/MMSegmentation教程/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /home/featurize/work/MMSegmentation教程/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /home/featurize/work/MMSegmentation教程/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:236: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 01/30 20:59:17 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 01/30 20:59:17 - mmengine - WARNING - The "hook" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:17 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /home/featurize/work/MMSegmentation教程/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %% [markdown]
# ## 开始训练
#
# 如果遇到报错`CUDA out of memeory`，重启实例或使用显存更高的实例即可。

# %%
runner.train()
# Out:
# 01/30 20:59:28 - mmengine - WARNING - The "loop" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:28 - mmengine - WARNING - The "dataset" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:28 - mmengine - WARNING - The "transform" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "data sampler" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "optimizer wrapper constructor" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "optimizer" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "optim_wrapper" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "parameter scheduler" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - WARNING - The "metric" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# /environment/miniconda3/lib/python3.7/site-packages/mmengine/evaluator/metric.py:47: UserWarning: The prefix is not set in metric class IoUMetric.
#   warnings.warn('The prefix is not set in metric class '
# 01/30 20:59:29 - mmengine - WARNING - The "weight initializer" registry in mmseg did not set import location. Fallback to call `mmseg.utils.register_all_modules` instead.
# 01/30 20:59:29 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 01/30 20:59:29 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# 01/30 20:59:30 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by local backend from path: pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for decode_head.conv_seg.weight: copying a param with shape torch.Size([19, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([8, 512, 1, 1]).
# size mismatch for decode_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([8]).
# size mismatch for auxiliary_head.conv_seg.weight: copying a param with shape torch.Size([19, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([8, 256, 1, 1]).
# size mismatch for auxiliary_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([8]).
# 01/30 20:59:31 - mmengine - INFO - Load checkpoint from pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# 01/30 20:59:31 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/MMSegmentation教程/mmsegmentation/work_dirs/tutorial.
# 01/30 20:59:34 - mmengine - INFO - Iter(train) [  10/1200]  lr: 9.9980e-03  eta: 0:06:11  time: 0.3125  data_time: 0.0128  memory: 5948  loss: 2.2595  decode.loss_ce: 1.5717  decode.acc_seg: 62.1440  aux.loss_ce: 0.6879  aux.acc_seg: 60.2165
# 01/30 20:59:35 - mmengine - INFO - Iter(train) [  20/1200]  lr: 9.9958e-03  eta: 0:04:39  time: 0.1609  data_time: 0.0097  memory: 3774  loss: 1.2567  decode.loss_ce: 0.7521  decode.acc_seg: 83.3816  aux.loss_ce: 0.5046  aux.acc_seg: 81.7845
# 01/30 20:59:37 - mmengine - INFO - Iter(train) [  30/1200]  lr: 9.9935e-03  eta: 0:04:07  time: 0.1614  data_time: 0.0097  memory: 3774  loss: 1.1868  decode.loss_ce: 0.7806  decode.acc_seg: 81.8761  aux.loss_ce: 0.4062  aux.acc_seg: 71.7441
# 01/30 20:59:39 - mmengine - INFO - Iter(train) [  40/1200]  lr: 9.9913e-03  eta: 0:03:50  time: 0.1611  data_time: 0.0097  memory: 3774  loss: 0.9229  decode.loss_ce: 0.6000  decode.acc_seg: 89.0293  aux.loss_ce: 0.3229  aux.acc_seg: 82.4090
# 01/30 20:59:40 - mmengine - INFO - Iter(train) [  50/1200]  lr: 9.9891e-03  eta: 0:03:40  time: 0.1623  data_time: 0.0104  memory: 3774  loss: 0.8620  decode.loss_ce: 0.5889  decode.acc_seg: 72.1944  aux.loss_ce: 0.2731  aux.acc_seg: 69.8792
# 01/30 20:59:42 - mmengine - INFO - Iter(train) [  60/1200]  lr: 9.9869e-03  eta: 0:03:33  time: 0.1637  data_time: 0.0100  memory: 3774  loss: 0.9914  decode.loss_ce: 0.6944  decode.acc_seg: 77.9385  aux.loss_ce: 0.2969  aux.acc_seg: 76.6789
# 01/30 20:59:43 - mmengine - INFO - Iter(train) [  70/1200]  lr: 9.9846e-03  eta: 0:03:26  time: 0.1598  data_time: 0.0085  memory: 3774  loss: 0.9159  decode.loss_ce: 0.6299  decode.acc_seg: 74.9596  aux.loss_ce: 0.2860  aux.acc_seg: 68.5534
# 01/30 20:59:44 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20230130_205906
# 01/30 20:59:45 - mmengine - INFO - Iter(train) [  80/1200]  lr: 9.9824e-03  eta: 0:03:22  time: 0.1629  data_time: 0.0101  memory: 3774  loss: 0.9187  decode.loss_ce: 0.6318  decode.acc_seg: 85.5808  aux.loss_ce: 0.2869  aux.acc_seg: 82.8896
# 01/30 20:59:47 - mmengine - INFO - Iter(train) [  90/1200]  lr: 9.9802e-03  eta: 0:03:17  time: 0.1580  data_time: 0.0084  memory: 3774  loss: 0.8504  decode.loss_ce: 0.5909  decode.acc_seg: 70.5946  aux.loss_ce: 0.2594  aux.acc_seg: 67.5557
# 01/30 20:59:48 - mmengine - INFO - Iter(train) [ 100/1200]  lr: 9.9779e-03  eta: 0:03:13  time: 0.1583  data_time: 0.0084  memory: 3774  loss: 0.7467  decode.loss_ce: 0.5127  decode.acc_seg: 75.8736  aux.loss_ce: 0.2340  aux.acc_seg: 71.8120
# 01/30 20:59:50 - mmengine - INFO - Iter(train) [ 110/1200]  lr: 9.9757e-03  eta: 0:03:10  time: 0.1663  data_time: 0.0106  memory: 3774  loss: 0.8860  decode.loss_ce: 0.6174  decode.acc_seg: 73.9944  aux.loss_ce: 0.2686  aux.acc_seg: 74.8381
# 01/30 20:59:52 - mmengine - INFO - Iter(train) [ 120/1200]  lr: 9.9735e-03  eta: 0:03:08  time: 0.1652  data_time: 0.0098  memory: 3774  loss: 0.8791  decode.loss_ce: 0.6072  decode.acc_seg: 77.5611  aux.loss_ce: 0.2718  aux.acc_seg: 72.7127
# 01/30 20:59:53 - mmengine - INFO - Iter(train) [ 130/1200]  lr: 9.9713e-03  eta: 0:03:06  time: 0.1689  data_time: 0.0126  memory: 3774  loss: 0.8003  decode.loss_ce: 0.5545  decode.acc_seg: 84.9445  aux.loss_ce: 0.2458  aux.acc_seg: 84.0511
# 01/30 20:59:55 - mmengine - INFO - Iter(train) [ 140/1200]  lr: 9.9690e-03  eta: 0:03:03  time: 0.1685  data_time: 0.0117  memory: 3774  loss: 0.8860  decode.loss_ce: 0.6187  decode.acc_seg: 74.9506  aux.loss_ce: 0.2672  aux.acc_seg: 74.3383
# 01/30 20:59:57 - mmengine - INFO - Iter(train) [ 150/1200]  lr: 9.9668e-03  eta: 0:03:01  time: 0.1677  data_time: 0.0122  memory: 3774  loss: 0.8755  decode.loss_ce: 0.6019  decode.acc_seg: 70.9701  aux.loss_ce: 0.2736  aux.acc_seg: 66.7454
# 01/30 20:59:58 - mmengine - INFO - Iter(train) [ 160/1200]  lr: 9.9646e-03  eta: 0:02:59  time: 0.1643  data_time: 0.0093  memory: 3774  loss: 0.8327  decode.loss_ce: 0.5763  decode.acc_seg: 72.3658  aux.loss_ce: 0.2564  aux.acc_seg: 78.4974
# 01/30 21:00:00 - mmengine - INFO - Iter(train) [ 170/1200]  lr: 9.9623e-03  eta: 0:02:57  time: 0.1656  data_time: 0.0114  memory: 3774  loss: 0.7410  decode.loss_ce: 0.5043  decode.acc_seg: 84.9482  aux.loss_ce: 0.2367  aux.acc_seg: 85.1649
# 01/30 21:00:02 - mmengine - INFO - Iter(train) [ 180/1200]  lr: 9.9601e-03  eta: 0:02:55  time: 0.1635  data_time: 0.0099  memory: 3774  loss: 0.7835  decode.loss_ce: 0.5394  decode.acc_seg: 84.4457  aux.loss_ce: 0.2441  aux.acc_seg: 83.2322
# 01/30 21:00:03 - mmengine - INFO - Iter(train) [ 190/1200]  lr: 9.9579e-03  eta: 0:02:53  time: 0.1689  data_time: 0.0126  memory: 3774  loss: 0.6602  decode.loss_ce: 0.4536  decode.acc_seg: 80.8674  aux.loss_ce: 0.2066  aux.acc_seg: 80.0848
# 01/30 21:00:05 - mmengine - INFO - Iter(train) [ 200/1200]  lr: 9.9557e-03  eta: 0:02:51  time: 0.1699  data_time: 0.0119  memory: 3774  loss: 0.8771  decode.loss_ce: 0.6043  decode.acc_seg: 73.2915  aux.loss_ce: 0.2728  aux.acc_seg: 71.2539
# 01/30 21:00:05 - mmengine - INFO - Saving checkpoint at 200 iterations
# 01/30 21:00:08 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:08  time: 0.0604  data_time: 0.0196  memory: 2909
# 01/30 21:00:08 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:04  time: 0.0179  data_time: 0.0023  memory: 810
# 01/30 21:00:08 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:04  time: 0.0372  data_time: 0.0027  memory: 2704
# 01/30 21:00:08 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:03  time: 0.0188  data_time: 0.0023  memory: 810
# 01/30 21:00:08 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:02  time: 0.0172  data_time: 0.0021  memory: 810
# 01/30 21:00:09 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:02  time: 0.0154  data_time: 0.0017  memory: 810
# 01/30 21:00:09 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:02  time: 0.0527  data_time: 0.0021  memory: 2704
# 01/30 21:00:10 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:02  time: 0.0711  data_time: 0.0025  memory: 2763
# 01/30 21:00:10 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:01  time: 0.0374  data_time: 0.0026  memory: 2704
# 01/30 21:00:10 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:01  time: 0.0212  data_time: 0.0025  memory: 1622
# 01/30 21:00:11 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:01  time: 0.0186  data_time: 0.0024  memory: 810
# 01/30 21:00:11 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0381  data_time: 0.0023  memory: 2704
# 01/30 21:00:11 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0187  data_time: 0.0022  memory: 810
# 01/30 21:00:11 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0270  data_time: 0.0025  memory: 2687
# 01/30 21:00:12 - mmengine - INFO - per class results:
# 01/30 21:00:12 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 83.37 | 91.63 |
# |  tree  | 57.58 |  78.9 |
# |  road  | 79.78 | 82.47 |
# | grass  | 62.68 | 90.87 |
# | water  | 43.89 | 61.69 |
# |  bldg  | 58.11 | 85.58 |
# |  mntn  |  0.0  |  0.0  |
# | fg obj | 43.13 | 48.86 |
# +--------+-------+-------+
# 01/30 21:00:12 - mmengine - INFO - Iter(val) [143/143]  aAcc: 77.1700  mIoU: 53.5700  mAcc: 67.5000
# 01/30 21:00:13 - mmengine - INFO - Iter(train) [ 210/1200]  lr: 9.9534e-03  eta: 0:02:49  time: 0.1685  data_time: 0.0117  memory: 3774  loss: 0.7928  decode.loss_ce: 0.5571  decode.acc_seg: 77.3819  aux.loss_ce: 0.2357  aux.acc_seg: 82.3583
# 01/30 21:00:15 - mmengine - INFO - Iter(train) [ 220/1200]  lr: 9.9512e-03  eta: 0:02:47  time: 0.1656  data_time: 0.0104  memory: 3774  loss: 0.6898  decode.loss_ce: 0.4764  decode.acc_seg: 79.3192  aux.loss_ce: 0.2134  aux.acc_seg: 76.8279
# 01/30 21:00:17 - mmengine - INFO - Iter(train) [ 230/1200]  lr: 9.9490e-03  eta: 0:02:45  time: 0.1620  data_time: 0.0093  memory: 3774  loss: 0.7772  decode.loss_ce: 0.5288  decode.acc_seg: 75.9897  aux.loss_ce: 0.2484  aux.acc_seg: 73.6939
# 01/30 21:00:18 - mmengine - INFO - Iter(train) [ 240/1200]  lr: 9.9467e-03  eta: 0:02:43  time: 0.1635  data_time: 0.0096  memory: 3774  loss: 0.6586  decode.loss_ce: 0.4558  decode.acc_seg: 84.4980  aux.loss_ce: 0.2028  aux.acc_seg: 84.3469
# 01/30 21:00:20 - mmengine - INFO - Iter(train) [ 250/1200]  lr: 9.9445e-03  eta: 0:02:41  time: 0.1624  data_time: 0.0087  memory: 3774  loss: 0.6500  decode.loss_ce: 0.4430  decode.acc_seg: 83.9746  aux.loss_ce: 0.2070  aux.acc_seg: 81.6545
# 01/30 21:00:21 - mmengine - INFO - Iter(train) [ 260/1200]  lr: 9.9423e-03  eta: 0:02:39  time: 0.1605  data_time: 0.0074  memory: 3774  loss: 0.6775  decode.loss_ce: 0.4559  decode.acc_seg: 87.5532  aux.loss_ce: 0.2216  aux.acc_seg: 81.8477
# 01/30 21:00:23 - mmengine - INFO - Iter(train) [ 270/1200]  lr: 9.9401e-03  eta: 0:02:37  time: 0.1639  data_time: 0.0095  memory: 3774  loss: 0.6181  decode.loss_ce: 0.4178  decode.acc_seg: 85.0382  aux.loss_ce: 0.2004  aux.acc_seg: 80.7588
# 01/30 21:00:25 - mmengine - INFO - Iter(train) [ 280/1200]  lr: 9.9378e-03  eta: 0:02:35  time: 0.1688  data_time: 0.0102  memory: 3774  loss: 0.5497  decode.loss_ce: 0.3790  decode.acc_seg: 78.2823  aux.loss_ce: 0.1707  aux.acc_seg: 76.8235
# 01/30 21:00:26 - mmengine - INFO - Iter(train) [ 290/1200]  lr: 9.9356e-03  eta: 0:02:34  time: 0.1657  data_time: 0.0093  memory: 3774  loss: 0.7578  decode.loss_ce: 0.5299  decode.acc_seg: 81.4603  aux.loss_ce: 0.2279  aux.acc_seg: 83.5277
# 01/30 21:00:28 - mmengine - INFO - Iter(train) [ 300/1200]  lr: 9.9334e-03  eta: 0:02:32  time: 0.1673  data_time: 0.0113  memory: 3774  loss: 0.6284  decode.loss_ce: 0.4219  decode.acc_seg: 91.1924  aux.loss_ce: 0.2065  aux.acc_seg: 90.8635
# 01/30 21:00:30 - mmengine - INFO - Iter(train) [ 310/1200]  lr: 9.9311e-03  eta: 0:02:30  time: 0.1607  data_time: 0.0081  memory: 3774  loss: 0.6231  decode.loss_ce: 0.4261  decode.acc_seg: 85.2171  aux.loss_ce: 0.1969  aux.acc_seg: 81.9083
# 01/30 21:00:31 - mmengine - INFO - Iter(train) [ 320/1200]  lr: 9.9289e-03  eta: 0:02:28  time: 0.1636  data_time: 0.0086  memory: 3774  loss: 0.7839  decode.loss_ce: 0.5317  decode.acc_seg: 90.0714  aux.loss_ce: 0.2522  aux.acc_seg: 88.7445
# 01/30 21:00:33 - mmengine - INFO - Iter(train) [ 330/1200]  lr: 9.9267e-03  eta: 0:02:26  time: 0.1680  data_time: 0.0100  memory: 3774  loss: 0.6540  decode.loss_ce: 0.4521  decode.acc_seg: 85.4467  aux.loss_ce: 0.2020  aux.acc_seg: 86.6953
# 01/30 21:00:35 - mmengine - INFO - Iter(train) [ 340/1200]  lr: 9.9245e-03  eta: 0:02:26  time: 0.2209  data_time: 0.0642  memory: 3774  loss: 0.5331  decode.loss_ce: 0.3660  decode.acc_seg: 88.3174  aux.loss_ce: 0.1671  aux.acc_seg: 87.1733
# 01/30 21:00:37 - mmengine - INFO - Iter(train) [ 350/1200]  lr: 9.9222e-03  eta: 0:02:24  time: 0.1604  data_time: 0.0072  memory: 3774  loss: 0.7035  decode.loss_ce: 0.4705  decode.acc_seg: 84.1297  aux.loss_ce: 0.2330  aux.acc_seg: 81.1026
# 01/30 21:00:38 - mmengine - INFO - Iter(train) [ 360/1200]  lr: 9.9200e-03  eta: 0:02:22  time: 0.1614  data_time: 0.0079  memory: 3774  loss: 0.6460  decode.loss_ce: 0.4326  decode.acc_seg: 88.1007  aux.loss_ce: 0.2135  aux.acc_seg: 77.4608
# 01/30 21:00:40 - mmengine - INFO - Iter(train) [ 370/1200]  lr: 9.9178e-03  eta: 0:02:20  time: 0.1614  data_time: 0.0079  memory: 3774  loss: 0.6565  decode.loss_ce: 0.4514  decode.acc_seg: 86.6745  aux.loss_ce: 0.2051  aux.acc_seg: 86.2554
# 01/30 21:00:42 - mmengine - INFO - Iter(train) [ 380/1200]  lr: 9.9155e-03  eta: 0:02:18  time: 0.1609  data_time: 0.0078  memory: 3774  loss: 0.6108  decode.loss_ce: 0.4127  decode.acc_seg: 87.6680  aux.loss_ce: 0.1981  aux.acc_seg: 84.1811
# 01/30 21:00:43 - mmengine - INFO - Iter(train) [ 390/1200]  lr: 9.9133e-03  eta: 0:02:17  time: 0.1654  data_time: 0.0101  memory: 3774  loss: 0.5870  decode.loss_ce: 0.3917  decode.acc_seg: 82.7298  aux.loss_ce: 0.1953  aux.acc_seg: 83.3968
# 01/30 21:00:45 - mmengine - INFO - Iter(train) [ 400/1200]  lr: 9.9111e-03  eta: 0:02:15  time: 0.1606  data_time: 0.0075  memory: 3774  loss: 0.6331  decode.loss_ce: 0.4333  decode.acc_seg: 85.9598  aux.loss_ce: 0.1999  aux.acc_seg: 79.7191
# 01/30 21:00:45 - mmengine - INFO - Saving checkpoint at 400 iterations
# 01/30 21:00:47 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:02  time: 0.0205  data_time: 0.0030  memory: 810
# 01/30 21:00:47 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:02  time: 0.0185  data_time: 0.0020  memory: 810
# 01/30 21:00:48 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:02  time: 0.0182  data_time: 0.0018  memory: 810
# 01/30 21:00:48 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:01  time: 0.0182  data_time: 0.0017  memory: 810
# 01/30 21:00:48 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:01  time: 0.0200  data_time: 0.0019  memory: 810
# 01/30 21:00:48 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:01  time: 0.0184  data_time: 0.0017  memory: 810
# 01/30 21:00:48 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:01  time: 0.0207  data_time: 0.0021  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:01  time: 0.0197  data_time: 0.0021  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:01  time: 0.0168  data_time: 0.0018  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:00  time: 0.0169  data_time: 0.0020  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:00  time: 0.0166  data_time: 0.0017  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0168  data_time: 0.0018  memory: 810
# 01/30 21:00:49 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0167  data_time: 0.0017  memory: 810
# 01/30 21:00:50 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0186  data_time: 0.0020  memory: 810
# 01/30 21:00:50 - mmengine - INFO - per class results:
# 01/30 21:00:50 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 88.28 | 92.33 |
# |  tree  | 63.08 | 86.65 |
# |  road  | 85.14 | 91.16 |
# | grass  | 57.41 | 76.73 |
# | water  | 64.57 | 66.23 |
# |  bldg  | 73.59 | 85.42 |
# |  mntn  | 20.93 | 21.79 |
# | fg obj | 67.62 | 78.45 |
# +--------+-------+-------+
# 01/30 21:00:50 - mmengine - INFO - Iter(val) [143/143]  aAcc: 84.7200  mIoU: 65.0800  mAcc: 74.8500
# 01/30 21:00:51 - mmengine - INFO - Iter(train) [ 410/1200]  lr: 9.9088e-03  eta: 0:02:13  time: 0.1645  data_time: 0.0096  memory: 3774  loss: 0.5716  decode.loss_ce: 0.3849  decode.acc_seg: 88.5379  aux.loss_ce: 0.1867  aux.acc_seg: 88.6134
# 01/30 21:00:53 - mmengine - INFO - Iter(train) [ 420/1200]  lr: 9.9066e-03  eta: 0:02:11  time: 0.1604  data_time: 0.0075  memory: 3774  loss: 0.6295  decode.loss_ce: 0.4336  decode.acc_seg: 81.9243  aux.loss_ce: 0.1959  aux.acc_seg: 85.8706
# 01/30 21:00:55 - mmengine - INFO - Iter(train) [ 430/1200]  lr: 9.9044e-03  eta: 0:02:09  time: 0.1639  data_time: 0.0089  memory: 3774  loss: 0.5826  decode.loss_ce: 0.3955  decode.acc_seg: 85.1988  aux.loss_ce: 0.1871  aux.acc_seg: 85.2531
# 01/30 21:00:56 - mmengine - INFO - Iter(train) [ 440/1200]  lr: 9.9022e-03  eta: 0:02:08  time: 0.1618  data_time: 0.0085  memory: 3774  loss: 0.6488  decode.loss_ce: 0.4463  decode.acc_seg: 88.6748  aux.loss_ce: 0.2025  aux.acc_seg: 86.7002
# 01/30 21:00:58 - mmengine - INFO - Iter(train) [ 450/1200]  lr: 9.8999e-03  eta: 0:02:06  time: 0.1620  data_time: 0.0084  memory: 3774  loss: 0.5460  decode.loss_ce: 0.3676  decode.acc_seg: 80.8769  aux.loss_ce: 0.1784  aux.acc_seg: 77.0727
# 01/30 21:00:59 - mmengine - INFO - Iter(train) [ 460/1200]  lr: 9.8977e-03  eta: 0:02:04  time: 0.1620  data_time: 0.0084  memory: 3774  loss: 0.4653  decode.loss_ce: 0.3091  decode.acc_seg: 93.9018  aux.loss_ce: 0.1561  aux.acc_seg: 90.9562
# 01/30 21:01:01 - mmengine - INFO - Iter(train) [ 470/1200]  lr: 9.8955e-03  eta: 0:02:02  time: 0.1619  data_time: 0.0084  memory: 3774  loss: 0.5827  decode.loss_ce: 0.4015  decode.acc_seg: 89.0183  aux.loss_ce: 0.1811  aux.acc_seg: 88.0597
# 01/30 21:01:03 - mmengine - INFO - Iter(train) [ 480/1200]  lr: 9.8932e-03  eta: 0:02:00  time: 0.1627  data_time: 0.0087  memory: 3774  loss: 0.6374  decode.loss_ce: 0.4362  decode.acc_seg: 85.8828  aux.loss_ce: 0.2012  aux.acc_seg: 85.7674
# 01/30 21:01:04 - mmengine - INFO - Iter(train) [ 490/1200]  lr: 9.8910e-03  eta: 0:01:59  time: 0.1624  data_time: 0.0086  memory: 3774  loss: 0.4984  decode.loss_ce: 0.3411  decode.acc_seg: 83.3416  aux.loss_ce: 0.1573  aux.acc_seg: 83.4171
# 01/30 21:01:06 - mmengine - INFO - Iter(train) [ 500/1200]  lr: 9.8888e-03  eta: 0:01:57  time: 0.1621  data_time: 0.0085  memory: 3774  loss: 0.4972  decode.loss_ce: 0.3361  decode.acc_seg: 83.3504  aux.loss_ce: 0.1611  aux.acc_seg: 81.9060
# 01/30 21:01:08 - mmengine - INFO - Iter(train) [ 510/1200]  lr: 9.8865e-03  eta: 0:01:55  time: 0.1623  data_time: 0.0085  memory: 3774  loss: 0.4811  decode.loss_ce: 0.3326  decode.acc_seg: 88.2994  aux.loss_ce: 0.1485  aux.acc_seg: 88.9062
# 01/30 21:01:09 - mmengine - INFO - Iter(train) [ 520/1200]  lr: 9.8843e-03  eta: 0:01:53  time: 0.1622  data_time: 0.0085  memory: 3774  loss: 0.5624  decode.loss_ce: 0.3781  decode.acc_seg: 77.2019  aux.loss_ce: 0.1842  aux.acc_seg: 74.6993
# 01/30 21:01:11 - mmengine - INFO - Iter(train) [ 530/1200]  lr: 9.8821e-03  eta: 0:01:52  time: 0.1621  data_time: 0.0085  memory: 3774  loss: 0.5331  decode.loss_ce: 0.3659  decode.acc_seg: 86.9731  aux.loss_ce: 0.1672  aux.acc_seg: 81.0451
# 01/30 21:01:12 - mmengine - INFO - Iter(train) [ 540/1200]  lr: 9.8799e-03  eta: 0:01:50  time: 0.1623  data_time: 0.0084  memory: 3774  loss: 0.6156  decode.loss_ce: 0.4099  decode.acc_seg: 86.5437  aux.loss_ce: 0.2057  aux.acc_seg: 86.4765
# 01/30 21:01:14 - mmengine - INFO - Iter(train) [ 550/1200]  lr: 9.8776e-03  eta: 0:01:48  time: 0.1652  data_time: 0.0097  memory: 3774  loss: 0.5344  decode.loss_ce: 0.3627  decode.acc_seg: 91.1836  aux.loss_ce: 0.1717  aux.acc_seg: 88.5436
# 01/30 21:01:16 - mmengine - INFO - Iter(train) [ 560/1200]  lr: 9.8754e-03  eta: 0:01:46  time: 0.1610  data_time: 0.0075  memory: 3774  loss: 0.5035  decode.loss_ce: 0.3407  decode.acc_seg: 83.5172  aux.loss_ce: 0.1628  aux.acc_seg: 83.5850
# 01/30 21:01:17 - mmengine - INFO - Iter(train) [ 570/1200]  lr: 9.8732e-03  eta: 0:01:45  time: 0.1610  data_time: 0.0076  memory: 3774  loss: 0.4694  decode.loss_ce: 0.3110  decode.acc_seg: 90.1898  aux.loss_ce: 0.1584  aux.acc_seg: 88.4712
# 01/30 21:01:19 - mmengine - INFO - Iter(train) [ 580/1200]  lr: 9.8709e-03  eta: 0:01:43  time: 0.1614  data_time: 0.0076  memory: 3774  loss: 0.5626  decode.loss_ce: 0.3767  decode.acc_seg: 87.9650  aux.loss_ce: 0.1858  aux.acc_seg: 78.6509
# 01/30 21:01:20 - mmengine - INFO - Iter(train) [ 590/1200]  lr: 9.8687e-03  eta: 0:01:41  time: 0.1610  data_time: 0.0075  memory: 3774  loss: 0.4725  decode.loss_ce: 0.3116  decode.acc_seg: 90.3333  aux.loss_ce: 0.1608  aux.acc_seg: 85.7217
# 01/30 21:01:22 - mmengine - INFO - Iter(train) [ 600/1200]  lr: 9.8665e-03  eta: 0:01:40  time: 0.1612  data_time: 0.0075  memory: 3774  loss: 0.5983  decode.loss_ce: 0.4121  decode.acc_seg: 87.3064  aux.loss_ce: 0.1862  aux.acc_seg: 86.6735
# 01/30 21:01:22 - mmengine - INFO - Saving checkpoint at 600 iterations
# 01/30 21:01:24 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:02  time: 0.0208  data_time: 0.0033  memory: 810
# 01/30 21:01:25 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:02  time: 0.0194  data_time: 0.0019  memory: 810
# 01/30 21:01:25 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:02  time: 0.0172  data_time: 0.0018  memory: 810
# 01/30 21:01:25 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:01  time: 0.0155  data_time: 0.0014  memory: 810
# 01/30 21:01:25 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:01  time: 0.0174  data_time: 0.0018  memory: 810
# 01/30 21:01:25 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:01  time: 0.0185  data_time: 0.0018  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:01  time: 0.0167  data_time: 0.0018  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:01  time: 0.0147  data_time: 0.0014  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:00  time: 0.0152  data_time: 0.0015  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:00  time: 0.0151  data_time: 0.0016  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:00  time: 0.0150  data_time: 0.0015  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0151  data_time: 0.0015  memory: 810
# 01/30 21:01:26 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0165  data_time: 0.0016  memory: 810
# 01/30 21:01:27 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0145  data_time: 0.0014  memory: 810
# 01/30 21:01:27 - mmengine - INFO - per class results:
# 01/30 21:01:27 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 88.19 | 92.17 |
# |  tree  | 65.67 |  77.0 |
# |  road  | 88.49 | 92.15 |
# | grass  | 75.25 | 87.38 |
# | water  |  80.1 | 88.95 |
# |  bldg  | 71.97 | 82.48 |
# |  mntn  | 26.28 | 37.45 |
# | fg obj |  64.4 | 85.34 |
# +--------+-------+-------+
# 01/30 21:01:27 - mmengine - INFO - Iter(val) [143/143]  aAcc: 86.0500  mIoU: 70.0400  mAcc: 80.3600
# 01/30 21:01:28 - mmengine - INFO - Iter(train) [ 610/1200]  lr: 9.8642e-03  eta: 0:01:38  time: 0.1647  data_time: 0.0094  memory: 3774  loss: 0.5017  decode.loss_ce: 0.3426  decode.acc_seg: 87.7001  aux.loss_ce: 0.1591  aux.acc_seg: 83.7522
# 01/30 21:01:30 - mmengine - INFO - Iter(train) [ 620/1200]  lr: 9.8620e-03  eta: 0:01:36  time: 0.1627  data_time: 0.0084  memory: 3774  loss: 0.5635  decode.loss_ce: 0.3849  decode.acc_seg: 91.1921  aux.loss_ce: 0.1786  aux.acc_seg: 88.4497
# 01/30 21:01:32 - mmengine - INFO - Iter(train) [ 630/1200]  lr: 9.8598e-03  eta: 0:01:34  time: 0.1621  data_time: 0.0077  memory: 3774  loss: 0.5266  decode.loss_ce: 0.3644  decode.acc_seg: 78.2250  aux.loss_ce: 0.1622  aux.acc_seg: 77.1177
# 01/30 21:01:33 - mmengine - INFO - Iter(train) [ 640/1200]  lr: 9.8575e-03  eta: 0:01:33  time: 0.1618  data_time: 0.0076  memory: 3774  loss: 0.5795  decode.loss_ce: 0.3976  decode.acc_seg: 88.0238  aux.loss_ce: 0.1819  aux.acc_seg: 89.2233
# 01/30 21:01:35 - mmengine - INFO - Iter(train) [ 650/1200]  lr: 9.8553e-03  eta: 0:01:31  time: 0.1657  data_time: 0.0092  memory: 3774  loss: 0.4989  decode.loss_ce: 0.3418  decode.acc_seg: 86.3772  aux.loss_ce: 0.1571  aux.acc_seg: 81.0222
# 01/30 21:01:36 - mmengine - INFO - Iter(train) [ 660/1200]  lr: 9.8531e-03  eta: 0:01:29  time: 0.1641  data_time: 0.0095  memory: 3774  loss: 0.5134  decode.loss_ce: 0.3534  decode.acc_seg: 86.4294  aux.loss_ce: 0.1600  aux.acc_seg: 86.5636
# 01/30 21:01:38 - mmengine - INFO - Iter(train) [ 670/1200]  lr: 9.8509e-03  eta: 0:01:28  time: 0.1665  data_time: 0.0114  memory: 3774  loss: 0.5544  decode.loss_ce: 0.3797  decode.acc_seg: 78.6202  aux.loss_ce: 0.1748  aux.acc_seg: 75.9792
# 01/30 21:01:40 - mmengine - INFO - Iter(train) [ 680/1200]  lr: 9.8486e-03  eta: 0:01:26  time: 0.1672  data_time: 0.0104  memory: 3774  loss: 0.5253  decode.loss_ce: 0.3567  decode.acc_seg: 88.1357  aux.loss_ce: 0.1686  aux.acc_seg: 78.3820
# 01/30 21:01:41 - mmengine - INFO - Iter(train) [ 690/1200]  lr: 9.8464e-03  eta: 0:01:24  time: 0.1665  data_time: 0.0105  memory: 3774  loss: 0.5125  decode.loss_ce: 0.3497  decode.acc_seg: 86.9710  aux.loss_ce: 0.1628  aux.acc_seg: 82.9622
# 01/30 21:01:43 - mmengine - INFO - Iter(train) [ 700/1200]  lr: 9.8442e-03  eta: 0:01:23  time: 0.1650  data_time: 0.0094  memory: 3774  loss: 0.5205  decode.loss_ce: 0.3574  decode.acc_seg: 88.5648  aux.loss_ce: 0.1631  aux.acc_seg: 84.8925
# 01/30 21:01:45 - mmengine - INFO - Iter(train) [ 710/1200]  lr: 9.8419e-03  eta: 0:01:21  time: 0.1617  data_time: 0.0072  memory: 3774  loss: 0.5736  decode.loss_ce: 0.3950  decode.acc_seg: 87.0193  aux.loss_ce: 0.1786  aux.acc_seg: 85.2049
# 01/30 21:01:46 - mmengine - INFO - Iter(train) [ 720/1200]  lr: 9.8397e-03  eta: 0:01:19  time: 0.1618  data_time: 0.0073  memory: 3774  loss: 0.4747  decode.loss_ce: 0.3155  decode.acc_seg: 89.1486  aux.loss_ce: 0.1592  aux.acc_seg: 84.4360
# 01/30 21:01:48 - mmengine - INFO - Iter(train) [ 730/1200]  lr: 9.8375e-03  eta: 0:01:18  time: 0.1616  data_time: 0.0073  memory: 3774  loss: 0.5615  decode.loss_ce: 0.3814  decode.acc_seg: 85.1208  aux.loss_ce: 0.1800  aux.acc_seg: 84.4686
# 01/30 21:01:50 - mmengine - INFO - Iter(train) [ 740/1200]  lr: 9.8352e-03  eta: 0:01:16  time: 0.1616  data_time: 0.0073  memory: 3774  loss: 0.5533  decode.loss_ce: 0.3763  decode.acc_seg: 88.6146  aux.loss_ce: 0.1770  aux.acc_seg: 87.4917
# 01/30 21:01:51 - mmengine - INFO - Iter(train) [ 750/1200]  lr: 9.8330e-03  eta: 0:01:14  time: 0.1619  data_time: 0.0073  memory: 3774  loss: 0.5964  decode.loss_ce: 0.4076  decode.acc_seg: 90.0932  aux.loss_ce: 0.1888  aux.acc_seg: 86.1863
# 01/30 21:01:53 - mmengine - INFO - Iter(train) [ 760/1200]  lr: 9.8308e-03  eta: 0:01:13  time: 0.1618  data_time: 0.0072  memory: 3774  loss: 0.6033  decode.loss_ce: 0.4070  decode.acc_seg: 84.8182  aux.loss_ce: 0.1964  aux.acc_seg: 83.2597
# 01/30 21:01:54 - mmengine - INFO - Iter(train) [ 770/1200]  lr: 9.8285e-03  eta: 0:01:11  time: 0.1618  data_time: 0.0073  memory: 3774  loss: 0.5850  decode.loss_ce: 0.3927  decode.acc_seg: 81.9482  aux.loss_ce: 0.1923  aux.acc_seg: 78.5364
# 01/30 21:01:56 - mmengine - INFO - Iter(train) [ 780/1200]  lr: 9.8263e-03  eta: 0:01:09  time: 0.1618  data_time: 0.0075  memory: 3774  loss: 0.4903  decode.loss_ce: 0.3360  decode.acc_seg: 91.0079  aux.loss_ce: 0.1543  aux.acc_seg: 89.9606
# 01/30 21:01:58 - mmengine - INFO - Iter(train) [ 790/1200]  lr: 9.8241e-03  eta: 0:01:08  time: 0.1622  data_time: 0.0077  memory: 3774  loss: 0.4900  decode.loss_ce: 0.3338  decode.acc_seg: 92.3807  aux.loss_ce: 0.1562  aux.acc_seg: 92.8909
# 01/30 21:01:59 - mmengine - INFO - Iter(train) [ 800/1200]  lr: 9.8218e-03  eta: 0:01:06  time: 0.1617  data_time: 0.0073  memory: 3774  loss: 0.5392  decode.loss_ce: 0.3654  decode.acc_seg: 84.8334  aux.loss_ce: 0.1738  aux.acc_seg: 83.2355
# 01/30 21:01:59 - mmengine - INFO - Saving checkpoint at 800 iterations
# 01/30 21:02:01 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:02  time: 0.0191  data_time: 0.0036  memory: 810
# 01/30 21:02:01 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:02  time: 0.0159  data_time: 0.0017  memory: 810
# 01/30 21:02:02 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:01  time: 0.0170  data_time: 0.0016  memory: 810
# 01/30 21:02:02 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:01  time: 0.0175  data_time: 0.0017  memory: 810
# 01/30 21:02:02 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:01  time: 0.0158  data_time: 0.0016  memory: 810
# 01/30 21:02:02 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:01  time: 0.0176  data_time: 0.0019  memory: 810
# 01/30 21:02:02 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:01  time: 0.0178  data_time: 0.0019  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:01  time: 0.0158  data_time: 0.0017  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:00  time: 0.0147  data_time: 0.0014  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:00  time: 0.0146  data_time: 0.0015  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:00  time: 0.0146  data_time: 0.0014  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0147  data_time: 0.0015  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0147  data_time: 0.0013  memory: 810
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0184  data_time: 0.0018  memory: 810
# 01/30 21:02:03 - mmengine - INFO - per class results:
# 01/30 21:02:03 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 87.85 | 91.26 |
# |  tree  | 68.38 | 80.11 |
# |  road  | 88.63 | 92.55 |
# | grass  | 77.93 | 85.06 |
# | water  | 86.88 | 94.34 |
# |  bldg  | 75.02 | 91.11 |
# |  mntn  | 25.89 | 28.54 |
# | fg obj | 67.47 | 82.23 |
# +--------+-------+-------+
# 01/30 21:02:03 - mmengine - INFO - Iter(val) [143/143]  aAcc: 87.5000  mIoU: 72.2500  mAcc: 80.6500
# 01/30 21:02:05 - mmengine - INFO - Iter(train) [ 810/1200]  lr: 9.8196e-03  eta: 0:01:04  time: 0.1725  data_time: 0.0112  memory: 3774  loss: 0.4926  decode.loss_ce: 0.3332  decode.acc_seg: 90.0574  aux.loss_ce: 0.1593  aux.acc_seg: 88.7704
# 01/30 21:02:07 - mmengine - INFO - Iter(train) [ 820/1200]  lr: 9.8174e-03  eta: 0:01:03  time: 0.1643  data_time: 0.0086  memory: 3774  loss: 0.4563  decode.loss_ce: 0.3024  decode.acc_seg: 91.0802  aux.loss_ce: 0.1539  aux.acc_seg: 90.4616
# 01/30 21:02:08 - mmengine - INFO - Iter(train) [ 830/1200]  lr: 9.8151e-03  eta: 0:01:01  time: 0.1626  data_time: 0.0080  memory: 3774  loss: 0.4061  decode.loss_ce: 0.2705  decode.acc_seg: 86.5955  aux.loss_ce: 0.1355  aux.acc_seg: 82.8302
# 01/30 21:02:10 - mmengine - INFO - Iter(train) [ 840/1200]  lr: 9.8129e-03  eta: 0:00:59  time: 0.1655  data_time: 0.0089  memory: 3774  loss: 0.5609  decode.loss_ce: 0.3846  decode.acc_seg: 84.9432  aux.loss_ce: 0.1764  aux.acc_seg: 82.5095
# 01/30 21:02:12 - mmengine - INFO - Iter(train) [ 850/1200]  lr: 9.8107e-03  eta: 0:00:58  time: 0.1615  data_time: 0.0076  memory: 3774  loss: 0.5143  decode.loss_ce: 0.3423  decode.acc_seg: 89.7243  aux.loss_ce: 0.1720  aux.acc_seg: 87.4970
# 01/30 21:02:13 - mmengine - INFO - Iter(train) [ 860/1200]  lr: 9.8084e-03  eta: 0:00:56  time: 0.1619  data_time: 0.0079  memory: 3774  loss: 0.4553  decode.loss_ce: 0.3113  decode.acc_seg: 88.8614  aux.loss_ce: 0.1440  aux.acc_seg: 88.3962
# 01/30 21:02:15 - mmengine - INFO - Iter(train) [ 870/1200]  lr: 9.8062e-03  eta: 0:00:54  time: 0.1612  data_time: 0.0075  memory: 3774  loss: 0.4012  decode.loss_ce: 0.2737  decode.acc_seg: 91.7071  aux.loss_ce: 0.1275  aux.acc_seg: 90.2923
# 01/30 21:02:17 - mmengine - INFO - Iter(train) [ 880/1200]  lr: 9.8040e-03  eta: 0:00:53  time: 0.1616  data_time: 0.0077  memory: 3774  loss: 0.4772  decode.loss_ce: 0.3162  decode.acc_seg: 92.3496  aux.loss_ce: 0.1610  aux.acc_seg: 89.1619
# 01/30 21:02:18 - mmengine - INFO - Iter(train) [ 890/1200]  lr: 9.8017e-03  eta: 0:00:51  time: 0.1614  data_time: 0.0075  memory: 3774  loss: 0.4477  decode.loss_ce: 0.2979  decode.acc_seg: 86.9953  aux.loss_ce: 0.1498  aux.acc_seg: 76.1440
# 01/30 21:02:20 - mmengine - INFO - Iter(train) [ 900/1200]  lr: 9.7995e-03  eta: 0:00:49  time: 0.1613  data_time: 0.0073  memory: 3774  loss: 0.4093  decode.loss_ce: 0.2795  decode.acc_seg: 88.8510  aux.loss_ce: 0.1298  aux.acc_seg: 87.8533
# 01/30 21:02:21 - mmengine - INFO - Iter(train) [ 910/1200]  lr: 9.7973e-03  eta: 0:00:48  time: 0.1610  data_time: 0.0073  memory: 3774  loss: 0.6629  decode.loss_ce: 0.4501  decode.acc_seg: 80.4097  aux.loss_ce: 0.2128  aux.acc_seg: 76.9562
# 01/30 21:02:23 - mmengine - INFO - Iter(train) [ 920/1200]  lr: 9.7951e-03  eta: 0:00:46  time: 0.1613  data_time: 0.0073  memory: 3774  loss: 0.5277  decode.loss_ce: 0.3614  decode.acc_seg: 79.5448  aux.loss_ce: 0.1662  aux.acc_seg: 77.7561
# 01/30 21:02:25 - mmengine - INFO - Iter(train) [ 930/1200]  lr: 9.7928e-03  eta: 0:00:44  time: 0.1610  data_time: 0.0073  memory: 3774  loss: 0.5636  decode.loss_ce: 0.3762  decode.acc_seg: 77.6855  aux.loss_ce: 0.1873  aux.acc_seg: 75.6024
# 01/30 21:02:26 - mmengine - INFO - Iter(train) [ 940/1200]  lr: 9.7906e-03  eta: 0:00:43  time: 0.1614  data_time: 0.0073  memory: 3774  loss: 0.5214  decode.loss_ce: 0.3439  decode.acc_seg: 86.2640  aux.loss_ce: 0.1775  aux.acc_seg: 85.2039
# 01/30 21:02:28 - mmengine - INFO - Iter(train) [ 950/1200]  lr: 9.7884e-03  eta: 0:00:41  time: 0.1610  data_time: 0.0073  memory: 3774  loss: 0.4630  decode.loss_ce: 0.3177  decode.acc_seg: 87.5280  aux.loss_ce: 0.1453  aux.acc_seg: 83.9774
# 01/30 21:02:29 - mmengine - INFO - Iter(train) [ 960/1200]  lr: 9.7861e-03  eta: 0:00:39  time: 0.1612  data_time: 0.0074  memory: 3774  loss: 0.4580  decode.loss_ce: 0.3123  decode.acc_seg: 80.8480  aux.loss_ce: 0.1457  aux.acc_seg: 81.2985
# 01/30 21:02:31 - mmengine - INFO - Iter(train) [ 970/1200]  lr: 9.7839e-03  eta: 0:00:38  time: 0.1609  data_time: 0.0072  memory: 3774  loss: 0.4792  decode.loss_ce: 0.3279  decode.acc_seg: 83.9271  aux.loss_ce: 0.1512  aux.acc_seg: 82.7035
# 01/30 21:02:33 - mmengine - INFO - Iter(train) [ 980/1200]  lr: 9.7817e-03  eta: 0:00:36  time: 0.1607  data_time: 0.0071  memory: 3774  loss: 0.4208  decode.loss_ce: 0.2854  decode.acc_seg: 91.9270  aux.loss_ce: 0.1353  aux.acc_seg: 86.8389
# 01/30 21:02:34 - mmengine - INFO - Iter(train) [ 990/1200]  lr: 9.7794e-03  eta: 0:00:34  time: 0.1606  data_time: 0.0070  memory: 3774  loss: 0.4376  decode.loss_ce: 0.2909  decode.acc_seg: 93.5591  aux.loss_ce: 0.1467  aux.acc_seg: 90.8745
# 01/30 21:02:36 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20230130_205906
# 01/30 21:02:36 - mmengine - INFO - Iter(train) [1000/1200]  lr: 9.7772e-03  eta: 0:00:33  time: 0.1611  data_time: 0.0072  memory: 3774  loss: 0.5176  decode.loss_ce: 0.3503  decode.acc_seg: 89.2061  aux.loss_ce: 0.1673  aux.acc_seg: 86.2758
# 01/30 21:02:36 - mmengine - INFO - Saving checkpoint at 1000 iterations
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:03  time: 0.0232  data_time: 0.0031  memory: 810
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:02  time: 0.0212  data_time: 0.0025  memory: 810
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:02  time: 0.0185  data_time: 0.0024  memory: 810
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:02  time: 0.0163  data_time: 0.0022  memory: 810
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:01  time: 0.0152  data_time: 0.0018  memory: 810
# 01/30 21:02:39 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:01  time: 0.0158  data_time: 0.0021  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:01  time: 0.0178  data_time: 0.0020  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:01  time: 0.0150  data_time: 0.0020  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:00  time: 0.0149  data_time: 0.0016  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:00  time: 0.0148  data_time: 0.0015  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:00  time: 0.0147  data_time: 0.0015  memory: 810
# 01/30 21:02:40 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0148  data_time: 0.0015  memory: 810
# 01/30 21:02:41 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0150  data_time: 0.0016  memory: 810
# 01/30 21:02:41 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0144  data_time: 0.0015  memory: 810
# 01/30 21:02:41 - mmengine - INFO - per class results:
# 01/30 21:02:41 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 87.99 | 91.25 |
# |  tree  | 63.92 | 74.09 |
# |  road  | 84.85 |  94.4 |
# | grass  | 57.79 | 61.71 |
# | water  | 76.87 | 91.59 |
# |  bldg  | 72.06 | 90.94 |
# |  mntn  | 16.14 | 18.27 |
# | fg obj | 68.29 | 81.59 |
# +--------+-------+-------+
# 01/30 21:02:41 - mmengine - INFO - Iter(val) [143/143]  aAcc: 85.2000  mIoU: 65.9900  mAcc: 75.4800
# 01/30 21:02:42 - mmengine - INFO - Iter(train) [1010/1200]  lr: 9.7750e-03  eta: 0:00:31  time: 0.1680  data_time: 0.0109  memory: 3774  loss: 0.5714  decode.loss_ce: 0.3927  decode.acc_seg: 87.9027  aux.loss_ce: 0.1787  aux.acc_seg: 86.4984
# 01/30 21:02:44 - mmengine - INFO - Iter(train) [1020/1200]  lr: 9.7727e-03  eta: 0:00:29  time: 0.1610  data_time: 0.0075  memory: 3774  loss: 0.5105  decode.loss_ce: 0.3435  decode.acc_seg: 87.2602  aux.loss_ce: 0.1669  aux.acc_seg: 87.3627
# 01/30 21:02:46 - mmengine - INFO - Iter(train) [1030/1200]  lr: 9.7705e-03  eta: 0:00:28  time: 0.1656  data_time: 0.0100  memory: 3774  loss: 0.5102  decode.loss_ce: 0.3425  decode.acc_seg: 90.1755  aux.loss_ce: 0.1677  aux.acc_seg: 89.1614
# 01/30 21:02:47 - mmengine - INFO - Iter(train) [1040/1200]  lr: 9.7683e-03  eta: 0:00:26  time: 0.1618  data_time: 0.0079  memory: 3774  loss: 0.5064  decode.loss_ce: 0.3458  decode.acc_seg: 90.6078  aux.loss_ce: 0.1607  aux.acc_seg: 89.4323
# 01/30 21:02:49 - mmengine - INFO - Iter(train) [1050/1200]  lr: 9.7660e-03  eta: 0:00:24  time: 0.1633  data_time: 0.0090  memory: 3774  loss: 0.4285  decode.loss_ce: 0.2823  decode.acc_seg: 87.0542  aux.loss_ce: 0.1462  aux.acc_seg: 78.8795
# 01/30 21:02:51 - mmengine - INFO - Iter(train) [1060/1200]  lr: 9.7638e-03  eta: 0:00:23  time: 0.1621  data_time: 0.0081  memory: 3774  loss: 0.4752  decode.loss_ce: 0.3191  decode.acc_seg: 87.3676  aux.loss_ce: 0.1561  aux.acc_seg: 85.3477
# 01/30 21:02:52 - mmengine - INFO - Iter(train) [1070/1200]  lr: 9.7616e-03  eta: 0:00:21  time: 0.1616  data_time: 0.0077  memory: 3774  loss: 0.4777  decode.loss_ce: 0.3164  decode.acc_seg: 84.2727  aux.loss_ce: 0.1613  aux.acc_seg: 84.2761
# 01/30 21:02:54 - mmengine - INFO - Iter(train) [1080/1200]  lr: 9.7593e-03  eta: 0:00:19  time: 0.1615  data_time: 0.0077  memory: 3774  loss: 0.4291  decode.loss_ce: 0.2986  decode.acc_seg: 88.1171  aux.loss_ce: 0.1305  aux.acc_seg: 90.6567
# 01/30 21:02:55 - mmengine - INFO - Iter(train) [1090/1200]  lr: 9.7571e-03  eta: 0:00:18  time: 0.1608  data_time: 0.0074  memory: 3774  loss: 0.5481  decode.loss_ce: 0.3797  decode.acc_seg: 87.0867  aux.loss_ce: 0.1684  aux.acc_seg: 86.9366
# 01/30 21:02:57 - mmengine - INFO - Iter(train) [1100/1200]  lr: 9.7549e-03  eta: 0:00:16  time: 0.1609  data_time: 0.0072  memory: 3774  loss: 0.4300  decode.loss_ce: 0.2893  decode.acc_seg: 91.0390  aux.loss_ce: 0.1407  aux.acc_seg: 87.4674
# 01/30 21:02:59 - mmengine - INFO - Iter(train) [1110/1200]  lr: 9.7526e-03  eta: 0:00:14  time: 0.1641  data_time: 0.0093  memory: 3774  loss: 0.4351  decode.loss_ce: 0.2952  decode.acc_seg: 86.4762  aux.loss_ce: 0.1400  aux.acc_seg: 84.3372
# 01/30 21:03:00 - mmengine - INFO - Iter(train) [1120/1200]  lr: 9.7504e-03  eta: 0:00:13  time: 0.1627  data_time: 0.0084  memory: 3774  loss: 0.4481  decode.loss_ce: 0.2997  decode.acc_seg: 88.7174  aux.loss_ce: 0.1484  aux.acc_seg: 85.9120
# 01/30 21:03:02 - mmengine - INFO - Iter(train) [1130/1200]  lr: 9.7482e-03  eta: 0:00:11  time: 0.1658  data_time: 0.0106  memory: 3774  loss: 0.4636  decode.loss_ce: 0.3149  decode.acc_seg: 89.2360  aux.loss_ce: 0.1487  aux.acc_seg: 88.1668
# 01/30 21:03:04 - mmengine - INFO - Iter(train) [1140/1200]  lr: 9.7459e-03  eta: 0:00:09  time: 0.1635  data_time: 0.0095  memory: 3774  loss: 0.4108  decode.loss_ce: 0.2773  decode.acc_seg: 89.6564  aux.loss_ce: 0.1336  aux.acc_seg: 87.6893
# 01/30 21:03:05 - mmengine - INFO - Iter(train) [1150/1200]  lr: 9.7437e-03  eta: 0:00:08  time: 0.1638  data_time: 0.0095  memory: 3774  loss: 0.4919  decode.loss_ce: 0.3261  decode.acc_seg: 90.6593  aux.loss_ce: 0.1658  aux.acc_seg: 86.0462
# 01/30 21:03:07 - mmengine - INFO - Iter(train) [1160/1200]  lr: 9.7414e-03  eta: 0:00:06  time: 0.1694  data_time: 0.0116  memory: 3774  loss: 0.4270  decode.loss_ce: 0.2844  decode.acc_seg: 88.3260  aux.loss_ce: 0.1426  aux.acc_seg: 86.1867
# 01/30 21:03:08 - mmengine - INFO - Iter(train) [1170/1200]  lr: 9.7392e-03  eta: 0:00:04  time: 0.1633  data_time: 0.0090  memory: 3774  loss: 0.4742  decode.loss_ce: 0.3089  decode.acc_seg: 91.3555  aux.loss_ce: 0.1653  aux.acc_seg: 91.6801
# 01/30 21:03:10 - mmengine - INFO - Iter(train) [1180/1200]  lr: 9.7370e-03  eta: 0:00:03  time: 0.1637  data_time: 0.0094  memory: 3774  loss: 0.4692  decode.loss_ce: 0.3225  decode.acc_seg: 85.5060  aux.loss_ce: 0.1467  aux.acc_seg: 83.3622
# 01/30 21:03:12 - mmengine - INFO - Iter(train) [1190/1200]  lr: 9.7347e-03  eta: 0:00:01  time: 0.1650  data_time: 0.0102  memory: 3774  loss: 0.3927  decode.loss_ce: 0.2671  decode.acc_seg: 89.6623  aux.loss_ce: 0.1255  aux.acc_seg: 88.9848
# 01/30 21:03:13 - mmengine - INFO - Iter(train) [1200/1200]  lr: 9.7325e-03  eta: 0:00:00  time: 0.1617  data_time: 0.0078  memory: 3774  loss: 0.4062  decode.loss_ce: 0.2735  decode.acc_seg: 88.4697  aux.loss_ce: 0.1328  aux.acc_seg: 86.5485
# 01/30 21:03:13 - mmengine - INFO - Saving checkpoint at 1200 iterations
# 01/30 21:03:16 - mmengine - INFO - Iter(val) [ 10/143]    eta: 0:00:02  time: 0.0209  data_time: 0.0035  memory: 810
# 01/30 21:03:16 - mmengine - INFO - Iter(val) [ 20/143]    eta: 0:00:02  time: 0.0223  data_time: 0.0023  memory: 810
# 01/30 21:03:17 - mmengine - INFO - Iter(val) [ 30/143]    eta: 0:00:02  time: 0.0210  data_time: 0.0022  memory: 810
# 01/30 21:03:17 - mmengine - INFO - Iter(val) [ 40/143]    eta: 0:00:02  time: 0.0196  data_time: 0.0019  memory: 810
# 01/30 21:03:17 - mmengine - INFO - Iter(val) [ 50/143]    eta: 0:00:01  time: 0.0212  data_time: 0.0023  memory: 810
# 01/30 21:03:17 - mmengine - INFO - Iter(val) [ 60/143]    eta: 0:00:01  time: 0.0201  data_time: 0.0023  memory: 810
# 01/30 21:03:17 - mmengine - INFO - Iter(val) [ 70/143]    eta: 0:00:01  time: 0.0198  data_time: 0.0021  memory: 810
# 01/30 21:03:18 - mmengine - INFO - Iter(val) [ 80/143]    eta: 0:00:01  time: 0.0206  data_time: 0.0022  memory: 810
# 01/30 21:03:18 - mmengine - INFO - Iter(val) [ 90/143]    eta: 0:00:01  time: 0.0205  data_time: 0.0021  memory: 810
# 01/30 21:03:18 - mmengine - INFO - Iter(val) [100/143]    eta: 0:00:00  time: 0.0206  data_time: 0.0021  memory: 810
# 01/30 21:03:18 - mmengine - INFO - Iter(val) [110/143]    eta: 0:00:00  time: 0.0199  data_time: 0.0022  memory: 810
# 01/30 21:03:18 - mmengine - INFO - Iter(val) [120/143]    eta: 0:00:00  time: 0.0203  data_time: 0.0020  memory: 810
# 01/30 21:03:19 - mmengine - INFO - Iter(val) [130/143]    eta: 0:00:00  time: 0.0207  data_time: 0.0022  memory: 810
# 01/30 21:03:19 - mmengine - INFO - Iter(val) [140/143]    eta: 0:00:00  time: 0.0196  data_time: 0.0022  memory: 810
# 01/30 21:03:19 - mmengine - INFO - per class results:
# 01/30 21:03:19 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  sky   | 88.64 | 93.74 |
# |  tree  | 68.34 | 83.68 |
# |  road  |  88.4 | 93.98 |
# | grass  | 76.58 | 87.44 |
# | water  | 78.94 | 86.94 |
# |  bldg  | 77.59 | 85.12 |
# |  mntn  | 20.94 | 21.97 |
# | fg obj | 69.83 |  85.5 |
# +--------+-------+-------+
# 01/30 21:03:19 - mmengine - INFO - Iter(val) [143/143]  aAcc: 87.8600  mIoU: 71.1600  mAcc: 79.8000
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(512, 8, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#     (conv_seg): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %% [markdown]
# ## 使用训练得到的模型预测图像

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

# %%
# 初始化模型
checkpoint_path = './work_dirs/tutorial/iter_1200.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')
# Out:
# Loads checkpoint by local backend from path: ./work_dirs/tutorial/iter_1200.pth

# %%
# 载入测试图像
img = mmcv.imread('iccv09Data/images/6000124.jpg')
# img = mmcv.imread('iccv09Data/images/6000295.jpg')

# %%
# 预测
result = inference_model(model, img)

# %%
# 可视化预测结果
visualization = show_result_pyplot(model, img, result, opacity=0.8, title='MMSeg', out_file='outputs/C.jpg')
plt.imshow(mmcv.bgr2rgb(visualization))
plt.show()

# %%
Image.open('outputs/C.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240 at 0x7F02CF0DE890>
