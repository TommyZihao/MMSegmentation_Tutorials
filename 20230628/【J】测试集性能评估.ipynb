# %% [markdown]
# # 测试集性能评估
#
# 同济子豪兄 2023-2-6 6-11 6-26

# %% [markdown]
# ## 进入MMSegmentation主目录

# %%
import os
os.chdir('mmsegmentation')

# %%
os.getcwd()
# Out:
# '/home/featurize/work/MMSegmentation教程20230625/mmsegmentation'

# %% [markdown]
# ## PSPNet-测试集精度指标

# %%
# PSPNet
# !python tools/test.py ZihaoDataset_PSPNet_20230626.py ./work_dirs/ZihaoDataset-PSPNet/iter_40000.pth

# %%
# PSPNet
# !python tools/test.py ZihaoDataset_PSPNet_20230626.py checkpoint/Zihao_PSPNet.pth
# Out:
# 06/28 09:34:36 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## Segformer-测试集精度指标

# %%
# Segformer
# !python tools/test.py ZihaoDataset_Segformer_20230626.py checkpoint/Zihao_Segformer.pth
# Out:
# 06/28 09:35:54 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 速度指标-FPS
#
# 测试集至少要有200张图片，否则跑不出分数

# %%
# !python tools/analysis_tools/benchmark.py ZihaoDataset_PSPNet_20230626.py ./work_dirs/ZihaoDataset-PSPNet/iter_30000.pth

# %% [markdown]
# ## UNet
#
# ```shell
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.52 | 91.87 | 92.19 | 92.19  |   92.52   | 91.87  |
# |    red     | 88.65 | 97.58 | 93.98 | 93.98  |   90.65   | 97.58  |
# |   green    | 22.92 | 23.83 |  37.3 |  37.3  |   85.79   | 23.83  |
# |   white    | 37.73 | 67.26 | 54.78 | 54.78  |   46.21   | 67.26  |
# | seed-black | 52.13 | 92.61 | 68.54 | 68.54  |    54.4   | 92.61  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/27 12:27:28 - mmengine - INFO - Iter(val) [11/11]    aAcc: 86.8800  mIoU: 47.8300  mAcc: 62.1900  mDice: 57.8000  mFscore: 69.3600  mPrecision: 73.9100  mRecall: 62.1900  data_time: 0.0083  time: 0.1124
# ```

# %% [markdown]
# ## PSPNet
#
# ```shell
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 97.59 | 98.49 | 98.78 | 98.78  |   99.07   | 98.49  |
# |    red     | 95.26 | 98.43 | 97.57 | 97.57  |   96.72   | 98.43  |
# |   green    | 90.52 | 93.63 | 95.03 | 95.03  |   96.46   | 93.63  |
# |   white    |  84.4 | 92.34 | 91.54 | 91.54  |   90.75   | 92.34  |
# | seed-black | 72.66 | 84.22 | 84.16 | 84.16  |   84.11   | 84.22  |
# | seed-white | 63.99 |  69.5 | 78.04 | 78.04  |   88.99   |  69.5  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 2023/06/28 18:43:06 - mmengine - INFO - Iter(val) [11/11]    aAcc: 97.5800  mIoU: 84.0700  mAcc: 89.4300  mDice: 90.8500  mFscore: 90.8500  mPrecision: 92.6800  mRecall: 89.4300  data_time: 0.0068  time: 0.0564
# ```

# %% [markdown]
# ## KNet
#
# ```shell
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 85.52 | 91.87 | 92.19 | 92.19  |   92.52   | 91.87  |
# |    red     | 88.65 | 97.58 | 93.98 | 93.98  |   90.65   | 97.58  |
# |   green    | 22.92 | 23.83 |  37.3 |  37.3  |   85.79   | 23.83  |
# |   white    | 37.73 | 67.26 | 54.78 | 54.78  |   46.21   | 67.26  |
# | seed-black | 52.13 | 92.61 | 68.54 | 68.54  |   54.39   | 92.61  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/27 21:19:26 - mmengine - INFO - Iter(test) [11/11]    aAcc: 86.8800  mIoU: 47.8300  mAcc: 62.1900  mDice: 57.8000  mFscore: 69.3600  mPrecision: 73.9100  mRecall: 62.1900  data_time: 0.0286  time: 0.8274
# ```

# %% [markdown]
# ## SegFormer
#
# ```shell
# 13000
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  80.5 |  80.9 |  89.2 |  89.2  |   99.38   |  80.9  |
# |    red     | 91.47 | 98.35 | 95.55 | 95.55  |   92.89   | 98.35  |
# |   green    | 63.05 | 93.02 | 77.34 | 77.34  |   66.19   | 93.02  |
# |   white    | 45.83 | 93.42 | 62.85 | 62.85  |   47.36   | 93.42  |
# | seed-black | 72.05 | 88.21 | 83.75 | 83.75  |   79.72   | 88.21  |
# | seed-white |  40.0 | 45.98 | 57.15 | 57.15  |   75.47   | 45.98  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/27 21:38:52 - mmengine - INFO - Iter(val) [11/11]    aAcc: 87.2100  mIoU: 65.4800  mAcc: 83.3100  mDice: 77.6400  mFscore: 77.6400  mPrecision: 76.8300  mRecall: 83.3100  data_time: 0.0089  time: 0.0573
# ```
#
# ```shell
# 40000
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 90.76 | 91.65 | 95.15 | 95.15  |   98.94   | 91.65  |
# |    red     | 90.94 |  99.0 | 95.25 | 95.25  |   91.78   |  99.0  |
# |   green    | 71.87 | 92.16 | 83.63 | 83.63  |   76.55   | 92.16  |
# |   white    | 73.56 | 90.82 | 84.77 | 84.77  |   79.47   | 90.82  |
# | seed-black | 76.11 | 86.28 | 86.44 | 86.44  |   86.59   | 86.28  |
# | seed-white | 35.83 | 36.63 | 52.76 | 52.76  |   94.29   | 36.63  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 06/27 22:23:32 - mmengine - INFO - Iter(val) [11/11]    aAcc: 93.4500  mIoU: 73.1800  mAcc: 82.7600  mDice: 83.0000  mFscore: 83.0000  mPrecision: 87.9400  mRecall: 82.7600  data_time: 0.0085  time: 0.0568
# ```

# %% [markdown]
# ## Mask2Former
#
# ```shell
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 82.17 | 94.65 | 90.21 | 90.21  |   86.18   | 94.65  |
# |    red     | 82.79 | 85.43 | 90.58 | 90.58  |    96.4   | 85.43  |
# |   green    | 59.94 |  62.7 | 74.95 | 74.95  |   93.14   |  62.7  |
# |   white    | 40.77 | 58.62 | 57.93 | 57.93  |   57.25   | 58.62  |
# | seed-black |  8.41 |  8.77 | 15.52 | 15.52  |   67.53   |  8.77  |
# | seed-white |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# ```
