# %% [markdown]
# # 训练语义分割模型
#
# 同济子豪兄 2023-2-13 6-12 6-25

# %% [markdown]
# ## 进入MMSegmentation主目录

# %%
import os
os.chdir('mmsegmentation')

# %%
os.getcwd()
# Out:
# '/home/featurize/work/MMSegmentation教程20230625/mmsegmentation'

# %% [markdown]
# ## 载入config配置文件（任选一个运行）

# %%
from mmengine import Config

# %%
# # UNet
# cfg = Config.fromfile('ZihaoDataset_UNet_20230626.py')

# %%
# PSPNet(推荐)
cfg = Config.fromfile('ZihaoDataset_PSPNet_20230628.py')

# %%
# # KNet
# cfg = Config.fromfile('ZihaoDataset_KNet_20230626.py')

# %%
# # SegFormer（推荐）
# cfg = Config.fromfile('ZihaoDataset_SegFormer_20230626.py')

# %%
# # Mask2Former
# cfg = Config.fromfile('ZihaoDataset_Mask2Former_20230626.py')

# %% [markdown]
# ## 准备训练

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 06/28 17:26:35 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.11 (default, Aug  3 2021, 15:09:35) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 4090
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
# ...

# %% [markdown]
# ## 开始训练
#
# 如果遇到报错`CUDA out of memeory`，可尝试以下步骤：
#
# 1. 调小 batch size
#
# 2. 左上角`内核-关闭所有内核`
#
# 3. 重启实例，或者使用显存更高的实例即可。

# %%
runner.train()
# Out:
# 06/28 17:26:46 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 06/28 17:26:47 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 06/28 17:26:47 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# 06/28 17:26:47 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 06/28 17:26:47 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/28 17:26:47 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/28 17:26:47 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/MMSegmentation教程20230625/mmsegmentation/work_dirs/ZihaoDataset-PSPNet.
# 06/28 17:26:51 - mmengine - INFO - Exp name: ZihaoDataset_PSPNet_20230628_20230628_172634
# ...

# %% [markdown]
# ## 训练结果保存至`work_dirs`目录
