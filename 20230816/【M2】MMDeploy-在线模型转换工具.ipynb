# %% [markdown]
# # MMDeploy-在线模型转换工具
#
# 同济子豪兄 2023-7-16

# %% [markdown]
# ## 在线模型转换工具
#
# https://platform.openmmlab.com/deploee

# %% [markdown]
# ## 在线模型测速工具
#
# https://platform.openmmlab.com/deploee/task-profile-list

# %% [markdown]
# ## MMDeploy微信答疑群
#
# 添加喵喵小助手微信号：OpenMMLabwx 回复 子豪兄模型部署
#
# 免费加入`MMDeploy模型部署、AI编译、边缘计算`交流群，有问必答
